# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
from math import ceil
from tqdm import tqdm_notebook
from collections import Counter, defaultdict
from operator import itemgetter

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import json

# %% [markdown]
# ## Govoritmoskva

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
govoritmoskva_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        govoritmoskva_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.govoritmoskva.ru%20OR%20domainis:govoritmoskva.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                govoritmoskva_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('govoritmoskva_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(govoritmoskva_20, f)
# Out:
# ...
# 2020.01.01 13
# 2020.01.01 27
# 2020.01.02 5
# 2020.01.02 19
# 2020.01.03 13
# 2020.01.03 19
# 2020.01.04 6
# 2020.01.04 26
# 2020.01.05 5
# 2020.01.05 19
# 2020.01.06 13
# 2020.01.06 23
# 2020.01.07 12
# 2020.01.07 14
# 2020.01.08 11
# 2020.01.08 20
# 2020.01.09 23
# 2020.01.09 28
# 2020.01.10 37
# 2020.01.10 57
# 2020.01.11 28
# 2020.01.11 31
# 2020.01.12 12
# 2020.01.12 29
# 2020.01.13 26
# 2020.01.13 44
# 2020.01.14 24
# 2020.01.14 44
# 2020.01.15 26
# 2020.01.15 45
# 2020.01.16 31
# 2020.01.16 28
# 2020.01.17 19
# 2020.01.17 44
# 2020.01.18 22
# 2020.01.18 33
# 2020.01.19 23
# 2020.01.19 21
# 2020.01.20 22
# 2020.01.20 43
# 2020.01.21 29
# 2020.01.21 32
# 2020.01.22 24
# 2020.01.22 46
# 2020.01.23 18
# 2020.01.23 39
# 2020.01.24 39
# 2020.01.24 24
# 2020.01.25 26
# 2020.01.25 34
# 2020.01.26 22
# 2020.01.26 23
# 2020.01.27 26
# 2020.01.27 33
# 2020.01.28 34
# 2020.01.28 42
# 2020.01.29 23
# 2020.01.29 35
# 2020.01.30 27
# 2020.01.30 50
# 2020.01.31 26
# 2020.01.31 44
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
govoritmoskva_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        govoritmoskva_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.govoritmoskva.ru%20OR%20domainis:govoritmoskva.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                govoritmoskva_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('govoritmoskva_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(govoritmoskva_19, f)
# Out:
# ...
# 2019.01.01 14
# 2019.01.01 33
# 2019.01.02 6
# 2019.01.02 23
# 2019.01.03 21
# 2019.01.03 26
# 2019.01.04 21
# 2019.01.04 23
# 2019.01.05 15
# 2019.01.05 14
# 2019.01.06 13
# 2019.01.06 11
# 2019.01.07 12
# 2019.01.07 19
# 2019.01.08 9
# 2019.01.08 21
# 2019.01.09 13
# 2019.01.09 23
# 2019.01.10 10
# 2019.01.10 34
# 2019.01.11 10
# 2019.01.11 35
# 2019.01.12 19
# 2019.01.12 28
# 2019.01.13 12
# 2019.01.13 21
# 2019.01.14 25
# 2019.01.14 36
# 2019.01.15 35
# 2019.01.15 34
# 2019.01.16 23
# 2019.01.16 44
# 2019.01.17 29
# 2019.01.17 34
# 2019.01.18 39
# 2019.01.18 53
# 2019.01.19 12
# 2019.01.19 39
# 2019.01.20 17
# 2019.01.20 32
# 2019.01.21 26
# 2019.01.21 42
# 2019.01.22 20
# 2019.01.22 42
# 2019.01.23 30
# 2019.01.23 36
# 2019.01.24 33
# 2019.01.24 40
# 2019.01.25 27
# 2019.01.25 40
# 2019.01.26 24
# 2019.01.26 32
# 2019.01.27 23
# 2019.01.27 22
# 2019.01.28 28
# 2019.01.28 44
# 2019.01.29 32
# 2019.01.29 34
# 2019.01.30 23
# 2019.01.30 38
# 2019.01.31 33
# 2019.01.31 45
# ...

# %%
govoritmoskva_19['2019.04.03']
# Out:
# ['https://govoritmoskva.ru/news/193554/',
#  'https://govoritmoskva.ru/news/193568/',
#  'https://govoritmoskva.ru/news/193567/',
#  'https://govoritmoskva.ru/news/193553/',
#  'https://govoritmoskva.ru/news/193566/',
#  'https://govoritmoskva.ru/news/193561/',
#  'https://govoritmoskva.ru/news/193569/',
#  'https://govoritmoskva.ru/news/193565/',
#  'https://govoritmoskva.ru/news/193563/',
#  'https://govoritmoskva.ru/news/193555/',
#  'https://govoritmoskva.ru/news/193564/',
#  'https://govoritmoskva.ru/news/193558/',
#  'https://govoritmoskva.ru/news/193559/',
#  'https://govoritmoskva.ru/news/193552/',
#  'https://govoritmoskva.ru/news/193531/',
#  'https://govoritmoskva.ru/news/193526/',
#  'https://govoritmoskva.ru/news/193541/',
#  'https://govoritmoskva.ru/news/193542/',
#  'https://govoritmoskva.ru/news/193536/',
#  'https://govoritmoskva.ru/news/193525/',
#  'https://govoritmoskva.ru/news/193539/',
#  'https://govoritmoskva.ru/news/193534/',
# ...

# %%
link = 'https://govoritmoskva.ru/news/193554/'
r = requests.get(link)
soup = BeautifulSoup(r.text)

# %%
' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'textContent').find_all('p')]).strip()])
# Out:
# 'В Волгограде суд восстановил право на пенсию вдове погибшего в Сирии офицера\n\n Муж Елены Петиной погиб 7 марта прошлого года в авиакатастрофе при выполнении боевых задач в арабской республике. Он был награждён медалью «Участника военной операции в Сирии» и орденом Мужества. Однако комиссариат отказался сделать отметку о праве вдовы на соцгарантии, ссылаясь на то, что у офицера не было удостоверения ветерана боевых действий. Как сообщает «Коммерсант», супруга военного подала в суд, который удовлетворил её требования. После этого комиссариат обжаловал решение. Однако областной суд, изучив материалы дела, оставил решение предыдущей инстанции в силе, передаёт «Интерфакс».'

# %%
govoritmoskva_2020 = []
for date in tqdm_notebook(list(govoritmoskva_20.keys())):
    for link in tqdm_notebook(govoritmoskva_20[date]):
#         if link not in pd.DataFrame(govoritmoskva_2020).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            govoritmoskva_2020.append({'Media':'govoritmoskva.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'textContent').find_all('p')]).strip()]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(govoritmoskva_2020).to_csv('govoritmoskva_2020.csv', encoding='utf-8')
pd.DataFrame(govoritmoskva_2020).to_csv('govoritmoskva_2020.csv', encoding='utf-8')
pd.DataFrame(govoritmoskva_2020)
# Out:
# ...
# https://govoritmoskva.ru/news/221303/
# ...
# https://govoritmoskva.ru/news/221700/
# ...
# https://govoritmoskva.ru/users/guests/5988/
# ...
# https://govoritmoskva.ru/users/guests/934/
# ...
# https://govoritmoskva.ru/blogs/1276/
# ...
#                  Media        Date                                   Link  \
# 0     govoritmoskva.ru  2020.01.01  https://govoritmoskva.ru/news/220804/
# 1     govoritmoskva.ru  2020.01.01  https://govoritmoskva.ru/news/220803/
# 2     govoritmoskva.ru  2020.01.01  https://govoritmoskva.ru/news/220800/
# 3     govoritmoskva.ru  2020.01.01  https://govoritmoskva.ru/news/220798/
# 4     govoritmoskva.ru  2020.01.01  https://govoritmoskva.ru/news/220813/
# ...                ...         ...                                    ...
# 3307  govoritmoskva.ru  2020.02.28  https://govoritmoskva.ru/news/226338/
# 3308  govoritmoskva.ru  2020.02.28  https://govoritmoskva.ru/news/226350/
# 3309  govoritmoskva.ru  2020.02.28  https://govoritmoskva.ru/news/226347/
# ...

# %%
govoritmoskva_2019 = []
for date in tqdm_notebook(list(govoritmoskva_19.keys())):
    for link in tqdm_notebook(govoritmoskva_19[date]):
#         if link not in pd.DataFragovoritmoskva_2019).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            govoritmoskva_2019.append({'Media':'govoritmoskva.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'textContent').find_all('p')]).strip()]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(govoritmoskva_2019).to_csv('govoritmoskva_2019.csv', encoding='utf-8')
pd.DataFrame(govoritmoskva_2019).to_csv('govoritmoskva_2019.csv', encoding='utf-8')
pd.DataFrame(govoritmoskva_2019)
# Out:
# ...
# https://govoritmoskva.ru/news/186157/
# ...
# https://govoritmoskva.ru/users/guests/5417/
# ...
# https://govoritmoskva.ru/users/guests/4600/
# ...
# https://govoritmoskva.ru/blogs/1225/
# ...
# https://govoritmoskva.ru/news/188937/
# ...
# https://govoritmoskva.ru/users/guests/3115/
# ...
# https://govoritmoskva.ru/blogs/1232/
# ...
# https://govoritmoskva.ru/users/guests/20/
# ...
# https://govoritmoskva.ru/blogs/1234/
# ...
# https://govoritmoskva.ru/users/guests/4161/
# ...
# https://govoritmoskva.ru/users/guests/2046/
# ...
# https://govoritmoskva.ru/blogs/1236/
# ...
# https://govoritmoskva.ru/users/guests/314/
# https://govoritmoskva.ru/users/guests/314/
# ...
# https://govoritmoskva.ru/blogs/1239/
# ...
# https://govoritmoskva.ru/news/195909/
# ...
# https://govoritmoskva.ru/news/196369/
# ...
# https://govoritmoskva.ru/users/guests/328/
# https://govoritmoskva.ru/users/guests/328/
# ...
# https://govoritmoskva.ru/users/guests/1726/
# ...
# https://govoritmoskva.ru/users/guests/59/
# ...
# https://govoritmoskva.ru/news/199693/
# https://govoritmoskva.ru/news/199693/
# ...

# %% [markdown]
# ## Echo

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
echo_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        echo_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.echo.msk.ru%20OR%20domainis:echo.msk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                echo_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('echo_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(echo_20, f)
# Out:
# ...
# 2020.01.01 72
# 2020.01.01 76
# 2020.01.02 76
# 2020.01.02 62
# 2020.01.03 94
# 2020.01.03 73
# 2020.01.04 87
# 2020.01.04 66
# 2020.01.05 79
# 2020.01.05 69
# 2020.01.06 87
# 2020.01.06 64
# 2020.01.07 70
# 2020.01.07 83
# 2020.01.08 101
# 2020.01.08 103
# 2020.01.09 103
# 2020.01.09 101
# 2020.01.10 89
# 2020.01.10 98
# 2020.01.11 92
# 2020.01.11 69
# 2020.01.12 75
# 2020.01.12 80
# 2020.01.13 97
# 2020.01.13 88
# 2020.01.14 82
# 2020.01.14 103
# 2020.01.15 112
# 2020.01.15 134
# 2020.01.16 104
# 2020.01.16 124
# 2020.01.17 107
# 2020.01.17 104
# 2020.01.18 65
# 2020.01.18 80
# 2020.01.19 82
# 2020.01.19 71
# 2020.01.20 97
# 2020.01.20 115
# 2020.01.21 71
# 2020.01.21 99
# 2020.01.22 90
# 2020.01.22 100
# 2020.01.23 92
# 2020.01.23 99
# 2020.01.24 105
# 2020.01.24 115
# 2020.01.25 71
# 2020.01.25 67
# 2020.01.26 84
# 2020.01.26 83
# 2020.01.27 86
# 2020.01.27 100
# 2020.01.28 101
# 2020.01.28 91
# 2020.01.29 64
# 2020.01.29 96
# 2020.01.30 76
# 2020.01.30 86
# 2020.01.31 97
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
echo_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        echo_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.echo.msk.ru%20OR%20domainis:echo.msk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                echo_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('echo_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(echo_19, f)
# Out:
# ...
# 2019.01.01 69
# 2019.01.01 100
# 2019.01.02 95
# 2019.01.02 78
# 2019.01.03 85
# 2019.01.03 114
# 2019.01.04 101
# 2019.01.04 107
# 2019.01.05 92
# 2019.01.05 92
# 2019.01.06 89
# 2019.01.06 95
# 2019.01.07 102
# 2019.01.07 93
# 2019.01.08 77
# 2019.01.08 97
# 2019.01.09 100
# 2019.01.09 117
# 2019.01.10 131
# 2019.01.10 118
# 2019.01.11 133
# 2019.01.11 106
# 2019.01.12 106
# 2019.01.12 87
# 2019.01.13 87
# 2019.01.13 78
# 2019.01.14 127
# 2019.01.14 91
# 2019.01.15 103
# 2019.01.15 107
# 2019.01.16 119
# 2019.01.16 106
# 2019.01.17 116
# 2019.01.17 113
# 2019.01.18 135
# 2019.01.18 121
# 2019.01.19 99
# 2019.01.19 92
# 2019.01.20 79
# 2019.01.20 78
# 2019.01.21 107
# 2019.01.21 115
# 2019.01.22 116
# 2019.01.22 102
# 2019.01.23 124
# 2019.01.23 127
# 2019.01.24 95
# 2019.01.24 113
# 2019.01.25 108
# 2019.01.25 96
# 2019.01.26 112
# 2019.01.26 97
# 2019.01.27 91
# 2019.01.27 92
# 2019.01.28 117
# 2019.01.28 95
# 2019.01.29 120
# 2019.01.29 113
# 2019.01.30 136
# 2019.01.30 118
# ...

# %%
with open('echo_links_2020.json', encoding = 'utf-8') as f:
    echo_20 = json.load(f)

# %%
with open('echo_links_2019.json', encoding = 'utf-8') as f:
    echo_19 = json.load(f)

# %%
echo_20['2020.02.15']
# Out:
# ['https://echo.msk.ru/news/2588678-echo.html',
#  'https://echo.msk.ru/news/2588668-echo/comments.html',
#  'https://echo.msk.ru/news/2588670-echo.html',
#  'https://echo.msk.ru/news/2588674-echo.html',
#  'https://echo.msk.ru/news/2588654-echo/comments.html',
#  'https://echo.msk.ru/news/2588668-echo.html',
#  'https://echo.msk.ru/news/2588656-echo.html',
#  'https://echo.msk.ru/news/2588664-echo.html',
#  'https://echo.msk.ru/news/2588654-echo.html',
#  'https://echo.msk.ru/news/2588658-echo.html',
#  'https://echo.msk.ru/news/2588652-echo.html',
#  'https://echo.msk.ru/news/2588644-echo/comments.html',
#  'https://echo.msk.ru/news/2588644-echo.html',
#  'https://echo.msk.ru/news/2588646-echo.html',
#  'https://echo.msk.ru/news/2588650-echo.html',
#  'https://echo.msk.ru/blog/currenttime/2588642-echo/',
#  'https://echo.msk.ru/blog/oleg_salagay/2588634-echo/',
#  'https://echo.msk.ru/news/2588640-echo.html',
#  'https://echo.msk.ru/programs/personalnovash/2588234-echo/q.html',
# ...

# %%
for link in echo_20['2020.02.15']:
# link = 'https://echo.msk.ru/news/2588678-echo.html'
    try:
        r = requests.get(link)
        soup = BeautifulSoup(r.text)

        ' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'typical').find_all('p')])])
    except (AttributeError, IndexError):
        print(link)
# Out:
# https://echo.msk.ru/news/2588668-echo/comments.html
# https://echo.msk.ru/news/2588654-echo/comments.html
# https://echo.msk.ru/news/2588644-echo/comments.html
# https://echo.msk.ru/programs/personalnovash/2588234-echo/q.html
# https://echo.msk.ru/blog/echomsk/2588608-echo/comments.html
# https://echo.msk.ru/news/2588612-echo/comments.html
# https://echo.msk.ru/news/2588614-echo/comments.html
# https://echo.msk.ru/news/2588610-echo/comments.html
# https://echo.msk.ru/news/2588602-echo/comments.html
# https://echo.msk.ru/news/2588596-echo/comments.html
# https://echo.msk.ru/news/2588592-echo/comments.html
# https://echo.msk.ru/news/2588588-echo/comments.html
# https://echo.msk.ru/news/2588568-echo/comments.html
# https://echo.msk.ru/news/2588574-echo/comments.html
# https://echo.msk.ru/news/2588556-echo/comments.html
# https://echo.msk.ru/programs/code/2588256-echo/q.html
# https://echo.msk.ru/news/2588572-echo/comments.html
# https://echo.msk.ru/news/2588570-echo/comments.html
# ...

# %%
echo_2020 = []
for date in tqdm_notebook(list(echo_20.keys())):
    for link in tqdm_notebook(echo_20[date]):
        if 'comments' not in link and 'programs' not in link:
#         if link not in pd.DataFrame(echo_2020).Link:
            try:
                r = requests.get(link)
                soup = BeautifulSoup(r.text)
                echo_2020.append({'Media':'echo.msk.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'typical').find_all('p')])]), 
                                      'Dep':'', 'Tags':[]})
            except (requests.exceptions.ConnectionError, AttributeError, 
                    IndexError, requests.exceptions.TooManyRedirects, ValueError):
                print(link)
    if date.endswith('1'):
        pd.DataFrame(echo_2020).to_csv('echo_2020.csv', encoding='utf-8')
pd.DataFrame(echo_2020).to_csv('echo_2020.csv', encoding='utf-8')
pd.DataFrame(echo_2020)
# Out:
# ...
# https://echo.msk.ru/news/2563983-echo.html
# https://echo.msk.ru/news/2564275-echo.html
# ...
# https://echo.msk.ru/blog/stavnijchuk/2570263-echo/
# ...
# https://echo.msk.ru/news/2570547-echo.html
# ...
# https://echo.msk.ru/blog/grishayudin/2575097-echo/
# ...
# https://echo.msk.ru/news/2584052-echo.html
# ...
# https://echo.msk.ru/news/2585992-echo.html
# ...
#             Media        Date  \
# 0     echo.msk.ru  2020.01.01
# 1     echo.msk.ru  2020.01.01
# 2     echo.msk.ru  2020.01.01
# 3     echo.msk.ru  2020.01.01
# 4     echo.msk.ru  2020.01.01
# ...           ...         ...
# 7768  echo.msk.ru  2020.02.28
# 7769  echo.msk.ru  2020.02.28
# 7770  echo.msk.ru  2020.02.28
# 7771  echo.msk.ru  2020.02.28
# 7772  echo.msk.ru  2020.02.28
#
#                                                  Link  \
# 0          https://echo.msk.ru/news/2564159-echo.html
# 1          https://echo.msk.ru/news/2564155-echo.html
# 2          https://echo.msk.ru/news/2564161-echo.html
# ...

# %%
echo_2019 = []
for date in tqdm_notebook(list(echo_19.keys())):
    for link in tqdm_notebook(echo_19[date]):
        if 'comments' not in link and 'programs' not in link:
#         if link not in pd.DataFrame(echo_2020).Link:
            try:
                r = requests.get(link)
                soup = BeautifulSoup(r.text)
                echo_2019.append({'Media':'echo.msk.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'typical').find_all('p')])]), 
                                      'Dep':'', 'Tags':[]})
            except (requests.exceptions.ConnectionError, AttributeError, 
                    IndexError, requests.exceptions.TooManyRedirects, ValueError):
                print(link)
    if date.endswith('1'):
        pd.DataFrame(echo_2019).to_csv('echo_2019.csv', encoding='utf-8')
pd.DataFrame(echo_2019).to_csv('echo_2019.csv', encoding='utf-8')
pd.DataFrame(echo_2019)
# Out:
# ...
# https://echo.msk.ru/news/2344339-echo.html
# https://echo.msk.ru/blog/rezn1/
# https://echo.msk.ru/blog/rezn1/2344565-echo/
# ...
# https://echo.msk.ru/blog/rezn1/2345515-echo/
# https://echo.msk.ru/news/2345495-echo.html
# https://echo.msk.ru/news/2345857-echo.html
# https://echo.msk.ru/blog/malkovamalkova/
# ...
# https://echo.msk.ru/news/2346317-echo.html
# ...
# https://echo.msk.ru/blog/yunis/2346595-echo/
# https://echo.msk.ru/blog/gallyamov_a/
# ...
# https://echo.msk.ru/blog/podkolzina/
# https://echo.msk.ru/blog/mkassimov/
# ...
# https://echo.msk.ru/blog/dalexy/
# ...
# https://echo.msk.ru/blog/davydovin/
# https://echo.msk.ru/blog/irina_reznik/
# ...
# https://echo.msk.ru/blog/d_matveev/
# ...
# https://echo.msk.ru/news/2353153-echo.html
# https://echo.msk.ru/blog/e_martyanova/
# https://echo.msk.ru/news/2352911-echo.html
# https://echo.msk.ru/blog/zair_akadyrov/
# ...
# https://echo.msk.ru/blog/dmitry_zimin/
# https://echo.msk.ru/blog/dmitry_zimin/
# ...
# https://echo.msk.ru/blog/statia_iz_regiona/2354293-echo/
# ...

# %% [markdown]
# ## Svoboda

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
svoboda_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        svoboda_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.svoboda.org%20OR%20domainis:svoboda.org)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                svoboda_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('svoboda_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(svoboda_20, f)
# Out:
# ...
# 2020.01.01 8
# 2020.01.01 14
# 2020.01.02 7
# 2020.01.02 8
# 2020.01.03 9
# 2020.01.03 11
# 2020.01.04 8
# 2020.01.04 8
# 2020.01.05 5
# 2020.01.05 11
# 2020.01.06 17
# 2020.01.06 12
# 2020.01.07 15
# 2020.01.07 16
# 2020.01.08 9
# 2020.01.08 10
# 2020.01.09 21
# 2020.01.09 19
# 2020.01.10 21
# 2020.01.10 19
# 2020.01.11 9
# 2020.01.11 10
# 2020.01.12 11
# 2020.01.12 11
# 2020.01.13 17
# 2020.01.13 21
# 2020.01.14 15
# 2020.01.14 27
# 2020.01.15 15
# 2020.01.15 17
# 2020.01.16 15
# 2020.01.16 26
# 2020.01.17 18
# 2020.01.17 15
# 2020.01.18 6
# 2020.01.18 9
# 2020.01.19 9
# 2020.01.19 14
# 2020.01.20 15
# 2020.01.20 18
# 2020.01.21 15
# 2020.01.21 20
# 2020.01.22 9
# 2020.01.22 23
# 2020.01.23 17
# 2020.01.23 22
# 2020.01.24 16
# 2020.01.24 16
# 2020.01.25 10
# 2020.01.25 7
# 2020.01.26 9
# 2020.01.26 12
# 2020.01.27 19
# 2020.01.27 18
# 2020.01.28 19
# 2020.01.28 18
# 2020.01.29 17
# 2020.01.29 20
# 2020.01.30 14
# 2020.01.30 27
# 2020.01.31 20
# 2020.01.31 17
# ...
# 2020.02.01 8
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
svoboda_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        svoboda_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.svoboda.org%20OR%20domainis:svoboda.org)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                svoboda_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('svoboda_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(svoboda_19, f)
# Out:
# ...
# 2019.01.01 9
# 2019.01.01 18
# 2019.01.02 6
# 2019.01.02 23
# 2019.01.03 16
# 2019.01.03 19
# 2019.01.04 21
# 2019.01.04 22
# 2019.01.05 12
# 2019.01.05 11
# 2019.01.06 10
# 2019.01.06 13
# 2019.01.07 16
# 2019.01.07 20
# 2019.01.08 20
# 2019.01.08 18
# 2019.01.09 26
# 2019.01.09 24
# 2019.01.10 25
# 2019.01.10 27
# 2019.01.11 18
# 2019.01.11 18
# 2019.01.12 11
# 2019.01.12 12
# 2019.01.13 12
# 2019.01.13 15
# 2019.01.14 19
# 2019.01.14 23
# 2019.01.15 21
# 2019.01.15 30
# 2019.01.16 20
# 2019.01.16 38
# 2019.01.17 24
# 2019.01.17 25
# 2019.01.18 13
# 2019.01.18 31
# 2019.01.19 13
# 2019.01.19 12
# 2019.01.20 9
# 2019.01.20 14
# 2019.01.21 19
# 2019.01.21 20
# 2019.01.22 21
# 2019.01.22 25
# 2019.01.23 18
# 2019.01.23 26
# 2019.01.24 18
# 2019.01.24 26
# 2019.01.25 24
# 2019.01.25 29
# 2019.01.26 10
# 2019.01.26 15
# 2019.01.27 10
# 2019.01.27 15
# 2019.01.28 14
# 2019.01.28 26
# 2019.01.29 15
# 2019.01.29 30
# 2019.01.30 17
# 2019.01.30 24
# 2019.01.31 20
# 2019.01.31 29
# ...

# %%
for link in svoboda_20['2020.02.17']:
    try:

# link = 'https://www.svoboda.org/a/30438402.html'
        r = requests.get(link)
        soup = BeautifulSoup(r.text)

        ' '.join([soup.h1.text.strip(), ' '.join([p.text for p in soup.find('div', 'wsw').find_all('p')])])
    except (AttributeError, IndexError):
        print(link)
# Out:
# https://www.svoboda.org/a/30413532.html

# %%
svoboda_2020 = []
for date in tqdm_notebook(list(svoboda_20.keys())):
    for link in tqdm_notebook(svoboda_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            svoboda_2020.append({'Media':'svoboda.org', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text.strip(), ' '.join([p.text for p in soup.find('div', 'wsw').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(svoboda_2020).to_csv('svoboda_2020.csv', encoding='utf-8')
pd.DataFrame(svoboda_2020).to_csv('svoboda_2020.csv', encoding='utf-8')
pd.DataFrame(svoboda_2020)
# Out:
# ...
# https://www.svoboda.org/a/30364239.html
# ...
# https://www.svoboda.org/a/30353368.html
# ...
# https://www.svoboda.org/a/30381321.html
# ...
# https://www.svoboda.org/a/30385754.html
# ...
# https://www.svoboda.org/a/30361955.html
# ...
# https://www.svoboda.org/a/30389109.html
# ...
# https://www.svoboda.org/a/30400739.html
# ...
# https://www.svoboda.org/a/30401932.html
# ...
# https://www.svoboda.org/a/30404112.html
# ...
# https://www.svoboda.org/a/30408684.html
# ...
# https://www.svoboda.org/a/pompeo-npr-kelly-ukraine-map-quiz/30406868.html
# https://www.svoboda.org/a/30410714.html
# ...
# https://www.svoboda.org/a/30411797.html
# ...
# https://www.svoboda.org/a/30414889.html
# ...
# https://www.svoboda.org/a/trump-state-of-the-union/30417753.html
# ...
# https://www.svoboda.org/a/30420882.html
# ...
# https://www.svoboda.org/a/30421973.html
# ...
# https://www.svoboda.org/a/30427278.html
# https://www.svoboda.org/a/30399885.html
# ...
# https://www.svoboda.org/a/30407147.html
# ...
# https://www.svoboda.org/a/rabinovich-in-dresden/30434418.html
# ...

# %%
svoboda_2019 = []
for date in tqdm_notebook(list(svoboda_19.keys())):
    for link in tqdm_notebook(svoboda_19[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            svoboda_2019.append({'Media':'svoboda.org', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text.strip(), ' '.join([p.text for p in soup.find('div', 'wsw').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(svoboda_2019).to_csv('svoboda_2019.csv', encoding='utf-8')
pd.DataFrame(svoboda_2019).to_csv('svoboda_2019.csv', encoding='utf-8')
pd.DataFrame(svoboda_2019)
# Out:
# ...
# https://www.svoboda.org/a/29687021.html
# https://www.svoboda.org/a/29686988.html
# ...
# https://www.svoboda.org/a/29696893.html
# ...
# https://www.svoboda.org/a/29697407.html
# ...
# https://www.svoboda.org/a/29668210.html
# ...
# https://www.svoboda.org/a/29713290.html
# ...
# https://www.svoboda.org/a/29717613.html
# ...
# https://www.svoboda.org/a/29726242.html
# https://www.svoboda.org/a/29726235.html
# ...
# https://www.svoboda.org/a/29730925.html
# ...
# https://www.svoboda.org/a/29728709.html
# ...
# https://www.svoboda.org/a/29696616.html
# ...
# https://www.svoboda.org/a/29741654.html
# https://www.svoboda.org/a/29742503.html
# https://www.svoboda.org/a/29741654.html
# ...
# https://www.svoboda.org/a/29748992.html
# ...
# https://www.svoboda.org/a/29751039.html
# ...
# https://www.svoboda.org/a/29750744.html
# ...
# https://www.svoboda.org/a/29759550.html
# ...
# https://www.svoboda.org/a/29762018.html
# ...
# https://www.svoboda.org/a/29766092.html
# https://www.svoboda.org/a/29765763.html
# ...
# https://www.svoboda.org/a/29767670.html
# ...

# %% [markdown]
# ## Radiovesti

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
radiovesti_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        radiovesti_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.radiovesti.ru%20OR%20domainis:radiovesti.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                radiovesti_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('radiovesti_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(radiovesti_20, f)
# Out:
# ...
# 2020.01.01 5
# 2020.01.01 2
# 2020.01.02 3
# 2020.01.02 3
# 2020.01.03 4
# 2020.01.03 1
# 2020.01.04 2
# 2020.01.04 5
# 2020.01.05 3
# 2020.01.05 3
# 2020.01.06 1
# 2020.01.06 3
# 2020.01.07 2
# 2020.01.07 5
# 2020.01.08 2
# 2020.01.08 2
# 2020.01.09 5
# 2020.01.09 5
# 2020.01.10 5
# 2020.01.10 8
# 2020.01.11 5
# 2020.01.11 3
# 2020.01.12 4
# 2020.01.12 3
# 2020.01.13 4
# 2020.01.13 8
# 2020.01.14 4
# 2020.01.14 8
# 2020.01.15 7
# 2020.01.15 3
# 2020.01.16 9
# 2020.01.16 8
# 2020.01.17 3
# 2020.01.17 9
# 2020.01.18 2
# 2020.01.18 1
# 2020.01.19 1
# 2020.01.19 4
# 2020.01.20 6
# 2020.01.20 9
# 2020.01.21 3
# 2020.01.21 7
# 2020.01.22 6
# 2020.01.22 3
# 2020.01.23 3
# 2020.01.23 5
# 2020.01.24 4
# 2020.01.24 4
# 2020.01.25 5
# 2020.01.25 1
# 2020.01.26 6
# 2020.01.26 4
# 2020.01.27 2
# 2020.01.27 6
# 2020.01.28 6
# 2020.01.28 6
# 2020.01.29 4
# 2020.01.29 5
# 2020.01.30 5
# 2020.01.30 5
# 2020.01.31 4
# 2020.01.31 6
# ...
# 2020.02.01 3
# 2020.02.01 5
# 2020.02.02 2
# 2020.02.02 3
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
radiovesti_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        radiovesti_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.radiovesti.ru%20OR%20domainis:radiovesti.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                radiovesti_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('radiovesti_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(radiovesti_19, f)
# Out:
# ...
# 2019.01.01 1
# 2019.01.01 2
# 2019.01.02 1
# 2019.01.02 5
# 2019.01.03 2
# 2019.01.03 2
# 2019.01.04 3
# 2019.01.04 3
# 2019.01.05 2
# 2019.01.05 3
# 2019.01.06 3
# 20190106
# 2019.01.07 2
# 2019.01.07 5
# 2019.01.08 3
# 2019.01.08 2
# 2019.01.09 2
# 2019.01.09 5
# 2019.01.10 3
# 2019.01.10 6
# 2019.01.11 3
# 2019.01.11 5
# 2019.01.12 4
# 2019.01.12 6
# 2019.01.13 3
# 2019.01.13 9
# 2019.01.14 7
# 2019.01.14 6
# 2019.01.15 3
# 2019.01.15 6
# 2019.01.16 3
# 2019.01.16 4
# 2019.01.17 5
# 2019.01.17 6
# 2019.01.18 6
# 2019.01.18 7
# 2019.01.19 8
# 2019.01.19 6
# 2019.01.20 4
# 2019.01.20 4
# 2019.01.21 5
# 2019.01.21 6
# 2019.01.22 3
# 2019.01.22 7
# 2019.01.23 3
# 2019.01.23 7
# 2019.01.24 4
# 2019.01.24 4
# 2019.01.25 5
# 2019.01.25 3
# 2019.01.26 5
# 2019.01.26 1
# 2019.01.27 3
# 2019.01.27 6
# 2019.01.28 5
# 2019.01.28 4
# 2019.01.29 7
# 2019.01.29 6
# 2019.01.30 4
# 2019.01.30 7
# 2019.01.31 2
# 2019.01.31 7
# ...
# 2019.02.01 3
# 2019.02.01 5
# 2019.02.02 1
# 2019.02.02 6
# ...

# %%
for link in radiovesti_20['2020.01.12']:
    try:
        r = requests.get(link)
        if r.status_code==200:
            r.encoding = 'utf-8'
            soup = BS(r.text)
            ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'insides-page__news__text').find_all('p')])])
    except (AttributeError, IndexError):
        print(link)

# %%
radiovesti_2020 = []
for date in tqdm_notebook(list(radiovesti_20.keys())):
    for link in tqdm_notebook(radiovesti_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            if r.status_code==200:
                r.encoding = 'utf-8'
                soup = BS(r.text)
                radiovesti_2020.append({'Media':'radiovesti.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'insides-page__news__text').find_all('p')])]), 
                                      'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(radiovesti_2020).to_csv('radiovesti_2020.csv', encoding='utf-8')
pd.DataFrame(radiovesti_2020).to_csv('radiovesti_2020.csv', encoding='utf-8')
pd.DataFrame(radiovesti_2020)
# Out:
# ...
#              Media        Date                                Link  \
# 0    radiovesti.ru  2020.01.01  http://radiovesti.ru/news/1256497/
# 1    radiovesti.ru  2020.01.01  http://radiovesti.ru/news/1256496/
# 2    radiovesti.ru  2020.01.01  http://radiovesti.ru/news/1256513/
# 3    radiovesti.ru  2020.01.01  http://radiovesti.ru/news/1256517/
# 4    radiovesti.ru  2020.01.01  http://radiovesti.ru/news/1256495/
# ..             ...         ...                                 ...
# 520  radiovesti.ru  2020.02.28  http://radiovesti.ru/news/1344735/
# 521  radiovesti.ru  2020.02.28  http://radiovesti.ru/news/1346225/
# 522  radiovesti.ru  2020.02.28  http://radiovesti.ru/news/1345752/
# 523  radiovesti.ru  2020.02.28  http://radiovesti.ru/news/1331102/
# 524  radiovesti.ru  2020.02.28  http://radiovesti.ru/news/1337638/
#
#                                                   Text Dep Tags
# 0    Почти 3 миллиона человек приняли участие в Мос...       []
# ...

# %%
radiovesti_2019 = []
for date in tqdm_notebook(list(radiovesti_19.keys())):
    for link in tqdm_notebook(radiovesti_19[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            if r.status_code==200:
                r.encoding = 'utf-8'
                soup = BS(r.text)
                radiovesti_2019.append({'Media':'radiovesti.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'insides-page__news__text').find_all('p')])]), 
                                      'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(radiovesti_2019).to_csv('radiovesti_2019.csv', encoding='utf-8')
pd.DataFrame(radiovesti_2019).to_csv('radiovesti_2019.csv', encoding='utf-8')
pd.DataFrame(radiovesti_2019)
# Out:
# ...
#               Media        Date                                Link  \
# 0     radiovesti.ru  2019.01.01  http://radiovesti.ru/news/1137303/
# 1     radiovesti.ru  2019.01.01  http://radiovesti.ru/news/1137464/
# 2     radiovesti.ru  2019.01.01  http://radiovesti.ru/news/1137463/
# 3     radiovesti.ru  2019.01.02  http://radiovesti.ru/news/1137563/
# 4     radiovesti.ru  2019.01.02  http://radiovesti.ru/news/1137963/
# ...             ...         ...                                 ...
# 3226  radiovesti.ru  2019.12.31  http://radiovesti.ru/news/1256394/
# 3227  radiovesti.ru  2019.12.31  http://radiovesti.ru/news/1256391/
# 3228  radiovesti.ru  2019.12.31  http://radiovesti.ru/news/1256390/
# 3229  radiovesti.ru  2019.12.31  http://radiovesti.ru/news/1256492/
# 3230  radiovesti.ru  2019.12.31  http://radiovesti.ru/news/1256505/
#
#                                                    Text Dep Tags
# 0     Тело восьмого погибшего обнаружено при разборе...       []
# ...

# %% [markdown]
# ## НТВ

# %%
link = 'https://www.ntv.ru/rest/news/day.jsp?dt=20200502'
r = requests.get(link)
soup = BS(r.text)

# %%
['https://www.ntv.ru'+a['href'] for a in soup.find('div', 'day_news').find_all('a') if 'novosti' in a['href']]
# Out:
# ['https://www.ntv.ru/novosti/2333361/',
#  'https://www.ntv.ru/novosti/2333321/',
#  'https://www.ntv.ru/novosti/2333240/',
#  'https://www.ntv.ru/novosti/2333260/',
#  'https://www.ntv.ru/novosti/2333305/',
#  'https://www.ntv.ru/novosti/2333306/',
#  'https://www.ntv.ru/novosti/2333280/',
#  'https://www.ntv.ru/novosti/2333301/',
#  'https://www.ntv.ru/novosti/2333440/',
#  'https://www.ntv.ru/novosti/2333303/',
#  'https://www.ntv.ru/novosti/2333304/',
#  'https://www.ntv.ru/novosti/2333520/',
#  'https://www.ntv.ru/novosti/2333302/',
#  'https://www.ntv.ru/novosti/2333500/',
#  'https://www.ntv.ru/novosti/2333424/',
#  'https://www.ntv.ru/novosti/2333481/',
#  'https://www.ntv.ru/novosti/2333480/',
#  'https://www.ntv.ru/novosti/2333482/',
#  'https://www.ntv.ru/novosti/2333460/',
#  'https://www.ntv.ru/novosti/2333401/',
#  'https://www.ntv.ru/novosti/2333422/',
#  'https://www.ntv.ru/novosti/2333420/',
#  'https://www.ntv.ru/novosti/2333380/',
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
ntv_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        ntv_20[f'2020.{month:02d}.{day+1:02d}'] = []
        try:
            url = f'https://www.ntv.ru/rest/news/day.jsp?dt={date}'
            r = requests.get(url)
            soup = BeautifulSoup(r.text)
            ntv_20[f'2020.{month:02d}.{day+1:02d}'] = ['https://www.ntv.ru'+a['href'] for a in soup.find('div', 'day_news').find_all('a') if 'novosti' in a['href']]
            print(f'2020.{month:02d}.{day+1:02d}', len(ntv_20[f'2020.{month:02d}.{day+1:02d}']))
        except (AttributeError, IndexError):
            print(date)
with open('ntv_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(ntv_20, f)
# Out:
# ...
# 2020.01.01 29
# 2020.01.02 48
# 2020.01.03 44
# 2020.01.04 40
# 2020.01.05 59
# 2020.01.06 63
# 2020.01.07 66
# 2020.01.08 44
# 2020.01.09 77
# 2020.01.10 67
# 2020.01.11 63
# 2020.01.12 69
# 2020.01.13 88
# 2020.01.14 69
# 2020.01.15 73
# 2020.01.16 64
# 2020.01.17 98
# 2020.01.18 69
# 2020.01.19 66
# 2020.01.20 64
# 2020.01.21 90
# 2020.01.22 71
# 2020.01.23 97
# 2020.01.24 101
# 2020.01.25 71
# 2020.01.26 60
# 2020.01.27 65
# 2020.01.28 73
# 2020.01.29 93
# 2020.01.30 92
# 2020.01.31 89
# ...
# 2020.02.01 45
# 2020.02.02 79
# 2020.02.03 80
# 2020.02.04 80
# 2020.02.05 93
# 2020.02.06 89
# 2020.02.07 81
# 2020.02.08 55
# 2020.02.09 52
# 2020.02.10 91
# 2020.02.11 83
# 2020.02.12 83
# 2020.02.13 56
# 2020.02.14 83
# 2020.02.15 57
# 2020.02.16 70
# 2020.02.17 88
# 2020.02.18 94
# 2020.02.19 70
# 2020.02.20 75
# 2020.02.21 66
# 2020.02.22 89
# 2020.02.23 89
# 2020.02.24 80
# 2020.02.25 61
# 2020.02.26 70
# 2020.02.27 70
# 2020.02.28 103

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
ntv_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        ntv_19[f'2019.{month:02d}.{day+1:02d}'] = []
        try:
            url = f'https://www.ntv.ru/rest/news/day.jsp?dt={date}'
            r = requests.get(url)
            soup = BeautifulSoup(r.text)
            ntv_19[f'2019.{month:02d}.{day+1:02d}'] = ['https://www.ntv.ru'+a['href'] for a in soup.find('div', 'day_news').find_all('a') if 'novosti' in a['href']]
            print(f'2019.{month:02d}.{day+1:02d}', len(ntv_19[f'2019.{month:02d}.{day+1:02d}']))
        except (AttributeError, IndexError):
            print(date)
with open('ntv_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(ntv_19, f)
# Out:
# ...
# 2019.01.01 52
# 2019.01.02 57
# 2019.01.03 44
# 2019.01.04 44
# 2019.01.05 75
# 2019.01.06 71
# 2019.01.07 56
# 2019.01.08 50
# 2019.01.09 84
# 2019.01.10 99
# 2019.01.11 115
# 2019.01.12 90
# 2019.01.13 58
# 2019.01.14 88
# 2019.01.15 91
# 2019.01.16 101
# 2019.01.17 103
# 2019.01.18 111
# 2019.01.19 52
# 2019.01.20 46
# 2019.01.21 95
# 2019.01.22 130
# 2019.01.23 119
# 2019.01.24 122
# 2019.01.25 96
# 2019.01.26 64
# 2019.01.27 72
# 2019.01.28 114
# 2019.01.29 113
# 2019.01.30 114
# 2019.01.31 94
# ...
# 2019.02.01 98
# 2019.02.02 63
# 2019.02.03 93
# 2019.02.04 137
# 2019.02.05 131
# 2019.02.06 98
# 2019.02.07 101
# 2019.02.08 97
# 2019.02.09 95
# 2019.02.10 101
# 2019.02.11 129
# 2019.02.12 90
# 2019.02.13 89
# 2019.02.14 95
# 2019.02.15 113
# 2019.02.16 90
# 2019.02.17 88
# 2019.02.18 82
# 2019.02.19 95
# 2019.02.20 92
# 2019.02.21 112
# 2019.02.22 102
# 2019.02.23 90
# 2019.02.24 53
# 2019.02.25 81
# 2019.02.26 96
# 2019.02.27 108
# 2019.02.28 105
# ...
# 2019.03.01 96
# 2019.03.02 71
# ...

# %%
ntv_20['2020.02.14']
# Out:
# ['https://www.ntv.ru/novosti/2292701/',
#  'https://www.ntv.ru/novosti/2292700/',
#  'https://www.ntv.ru/novosti/2292680/',
#  'https://www.ntv.ru/novosti/2292660/',
#  'https://www.ntv.ru/novosti/2292661/',
#  'https://www.ntv.ru/novosti/2292584/',
#  'https://www.ntv.ru/novosti/2292625/',
#  'https://www.ntv.ru/novosti/2292601/',
#  'https://www.ntv.ru/novosti/2292623/',
#  'https://www.ntv.ru/novosti/2292624/',
#  'https://www.ntv.ru/novosti/2292620/',
#  'https://www.ntv.ru/novosti/2292640/',
#  'https://www.ntv.ru/novosti/2292621/',
#  'https://www.ntv.ru/novosti/2292622/',
#  'https://www.ntv.ru/novosti/2292602/',
#  'https://www.ntv.ru/novosti/2292583/',
#  'https://www.ntv.ru/novosti/2292600/',
#  'https://www.ntv.ru/novosti/2292580/',
#  'https://www.ntv.ru/novosti/2292546/',
#  'https://www.ntv.ru/novosti/2292582/',
#  'https://www.ntv.ru/novosti/2292581/',
#  'https://www.ntv.ru/novosti/2292544/',
#  'https://www.ntv.ru/novosti/2292542/',
# ...

# %%
for link in ntv_20['2020.02.14']:
# link = 'https://www.ntv.ru/novosti/2292701/'
    try:
        r = requests.get(link)
        soup = BS(r.text)

        ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'inpagebody').find_all('p')])]).replace('\xa0', ' ')
    except (AttributeError, IndexError):
        print(link)

# %%
ntv_2020 = []
for date in tqdm_notebook(list(ntv_20.keys())):
    for link in tqdm_notebook(ntv_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            ntv_2020.append({'Media':'ntv.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'inpagebody').find_all('p')])]).replace('\xa0', ' '), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(ntv_2020).to_csv('ntv_2020.csv', encoding='utf-8')
pd.DataFrame(ntv_2020).to_csv('ntv_2020.csv', encoding='utf-8')
pd.DataFrame(ntv_2020)
# Out:
# ...
#        Media        Date                                 Link  \
# 0     ntv.ru  2020.01.01  https://www.ntv.ru/novosti/2273521/
# 1     ntv.ru  2020.01.01  https://www.ntv.ru/novosti/2273520/
# 2     ntv.ru  2020.01.01  https://www.ntv.ru/novosti/2273580/
# 3     ntv.ru  2020.01.01  https://www.ntv.ru/novosti/2273560/
# 4     ntv.ru  2020.01.01  https://www.ntv.ru/novosti/2273561/
# ...      ...         ...                                  ...
# 4289  ntv.ru  2020.02.28  https://www.ntv.ru/novosti/2298344/
# 4290  ntv.ru  2020.02.28  https://www.ntv.ru/novosti/2298323/
# 4291  ntv.ru  2020.02.28  https://www.ntv.ru/novosti/2298320/
# 4292  ntv.ru  2020.02.28  https://www.ntv.ru/novosti/2298322/
# 4293  ntv.ru  2020.02.28  https://www.ntv.ru/novosti/2298321/
#
#                                                    Text Dep Tags
# 0     Необычный соцпроект набирает популярность в Ле...       []
# 1     Британская газета еще в 1997 году предсказала ...       []
# ...

# %%
with open('ntv_links_2019.json') as f:
    ntv_19 = json.load(f)

# %%
ntv_2019 = pd.read_csv('ntv_2019.csv')
len(ntv_2019.Date.unique())
# Out:
# 315

# %%
ntv_2019_add = []
for date in tqdm_notebook(list(ntv_19.keys())[315:]):
    for link in tqdm_notebook(ntv_19[date]):
        if link not in ntv_2019.Link:
            try:
                r = requests.get(link)
                soup = BS(r.text)
                ntv_2019_add.append({'Media':'ntv.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'inpagebody').find_all('p')])]).replace('\xa0', ' '), 
                                      'Dep':'', 'Tags':[]})
            except (requests.exceptions.ConnectionError, AttributeError, 
                    IndexError, requests.exceptions.TooManyRedirects, ValueError):
                print(link)
    if date.endswith('1'):
        pd.DataFrame(ntv_2019_add).to_csv('ntv_2019_add.csv', encoding='utf-8')
pd.DataFrame(ntv_2019_add).to_csv('ntv_2019_add.csv', encoding='utf-8')
pd.DataFrame(ntv_2019_add)
# Out:
# ...
# https://www.ntv.ru/novosti/2254587/
# ...
# https://www.ntv.ru/novosti/2257660/
# ...
# https://www.ntv.ru/novosti/2270785/
# ...
# https://www.ntv.ru/novosti/2272021/
# ...
#        Media        Date                                 Link  \
# 0     ntv.ru  2019.11.12  https://www.ntv.ru/novosti/2254402/
# 1     ntv.ru  2019.11.12  https://www.ntv.ru/novosti/2254401/
# 2     ntv.ru  2019.11.12  https://www.ntv.ru/novosti/2254380/
# 3     ntv.ru  2019.11.12  https://www.ntv.ru/novosti/2254360/
# 4     ntv.ru  2019.11.12  https://www.ntv.ru/novosti/2254361/
# ...      ...         ...                                  ...
# 3902  ntv.ru  2019.12.31  https://www.ntv.ru/novosti/2273044/
# 3903  ntv.ru  2019.12.31  https://www.ntv.ru/novosti/2273043/
# 3904  ntv.ru  2019.12.31  https://www.ntv.ru/novosti/2273042/
# 3905  ntv.ru  2019.12.31  https://www.ntv.ru/novosti/2273021/
# 3906  ntv.ru  2019.12.31  https://www.ntv.ru/novosti/2273020/
#
#                                                    Text Dep Tags
# ...

# %% [markdown]
# ## Дождь

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
tvrain_20 = dict()
year = '2020'
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
#         date = f'2020{month:02d}{day+1:02d}'
        links_temp = list()
        url = f'https://tvrain.ru/archive/?search_teleshow_cat=&search_year={year}&search_month={month}&search_day={day+1}&query=&page={page+1}'
        r = requests.get(url)
        soup = BeautifulSoup(r.text)
        num_of_pages = ceil(int(soup.find('a', 'filter__items__item--label_brand').text.strip().split()[-1])/20)
        print('num_of_news', int(soup.find('a', 'filter__items__item--label_brand').text.strip().split()[-1]),
             'num_of pages', num_of_pages)
        for page in range(num_of_pages):
            try:
                url = f'https://tvrain.ru/archive/?search_teleshow_cat=&search_year={year}&search_month={month}&search_day={day}&query=&page={page+1}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                links_temp.extend(['https://tvrain.ru'+a['href'] for a in soup.find_all('a', 'chrono_list__item__info__name')])
                print(f'2020.{month:02d}.{day+1:02d}', len(links_temp))
#                 page+=1
            except (AttributeError, IndexError):
                print(date)
#             if len(links_temp) == number:
#                 break
        tvrain_20[f'2020.{month:02d}.{day+1:02d}'] = links_temp
        
with open('tvrain_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(tvrain_20, f)
# Out:
# ...
# num_of_news 15 num_of pages 1
# 2020.01.01 10
# num_of_news 26 num_of pages 2
# 2020.01.02 10
# 2020.01.02 20
# num_of_news 25 num_of pages 2
# 2020.01.03 10
# 2020.01.03 16
# num_of_news 17 num_of pages 1
# 2020.01.04 10
# num_of_news 14 num_of pages 1
# 2020.01.05 10
# num_of_news 28 num_of pages 2
# 2020.01.06 10
# 2020.01.06 20
# num_of_news 27 num_of pages 2
# 2020.01.07 10
# 2020.01.07 18
# num_of_news 30 num_of pages 2
# 2020.01.08 10
# 2020.01.08 17
# num_of_news 70 num_of pages 4
# 2020.01.09 10
# 2020.01.09 20
# 2020.01.09 30
# 2020.01.09 40
# num_of_news 71 num_of pages 4
# 2020.01.10 10
# 2020.01.10 30
# 2020.01.10 50
# 2020.01.10 60
# num_of_news 23 num_of pages 2
# 2020.01.11 10
# 2020.01.11 30
# num_of_news 26 num_of pages 2
# 2020.01.12 10
# 2020.01.12 13
# num_of_news 70 num_of pages 4
# 2020.01.13 10
# 2020.01.13 16
# 2020.01.13 22
# 2020.01.13 28
# num_of_news 74 num_of pages 4
# 2020.01.14 10
# 2020.01.14 30
# 2020.01.14 50
# 2020.01.14 60
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
tvrain_19 = dict()
year = '2019'
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
#         date = f'2020{month:02d}{day+1:02d}'
        links_temp = list()
        url = f'https://tvrain.ru/archive/?search_teleshow_cat=&search_year={year}&search_month={month}&search_day={day+1}&query=&page={page+1}'
        r = requests.get(url)
        soup = BeautifulSoup(r.text)
        num_of_pages = ceil(int(soup.find('a', 'filter__items__item--label_brand').text.strip().split()[-1])/20)
        print('num_of_news', int(soup.find('a', 'filter__items__item--label_brand').text.strip().split()[-1]),
             'num_of pages', num_of_pages)
        for page in range(num_of_pages):
            try:
                url = f'https://tvrain.ru/archive/?search_teleshow_cat=&search_year={year}&search_month={month}&search_day={day}&query=&page={page+1}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                links_temp.extend(['https://tvrain.ru'+a['href'] for a in soup.find_all('a', 'chrono_list__item__info__name')])
                print(f'2019.{month:02d}.{day+1:02d}', len(links_temp))
#                 page+=1
            except (AttributeError, IndexError):
                print(date)
#             if len(links_temp) == number:
#                 break
        tvrain_19[f'2019.{month:02d}.{day+1:02d}'] = links_temp
        
with open('tvrain_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(tvrain_19, f)
# Out:
# ...
# num_of_news 21 num_of pages 2
# 2019.01.01 10
# 2019.01.01 30
# num_of_news 22 num_of pages 2
# 2019.01.02 10
# 2019.01.02 11
# num_of_news 25 num_of pages 2
# 2019.01.03 10
# 2019.01.03 12
# num_of_news 23 num_of pages 2
# 2019.01.04 10
# 2019.01.04 15
# num_of_news 19 num_of pages 1
# 2019.01.05 10
# num_of_news 21 num_of pages 2
# 2019.01.06 10
# 2019.01.06 20
# num_of_news 18 num_of pages 1
# 2019.01.07 10
# num_of_news 23 num_of pages 2
# 2019.01.08 10
# 2019.01.08 20
# num_of_news 60 num_of pages 3
# 2019.01.09 10
# 2019.01.09 13
# 2019.01.09 16
# num_of_news 70 num_of pages 4
# 2019.01.10 10
# 2019.01.10 30
# 2019.01.10 50
# 2019.01.10 70
# num_of_news 59 num_of pages 3
# 2019.01.11 10
# 2019.01.11 30
# 2019.01.11 50
# num_of_news 20 num_of pages 1
# 2019.01.12 10
# num_of_news 17 num_of pages 1
# 2019.01.13 10
# num_of_news 60 num_of pages 3
# 2019.01.14 10
# 2019.01.14 20
# 2019.01.14 30
# num_of_news 63 num_of pages 4
# 2019.01.15 10
# 2019.01.15 30
# 2019.01.15 50
# ...

# %%
link = f'https://tvrain.ru/archive/?search_teleshow_cat=&search_year=2020&search_month=1&search_day=1&query=&page=1'
r = requests.get(link)
soup = BS(r.text)
int(soup.find('a', 'filter__items__item--label_brand').text.strip().split()[-1])

['https://tvrain.ru'+a['href'] for a in soup.find_all('a', 'chrono_list__item__info__name')]
# Out:
# ['https://tvrain.ru/news/palau_stala_pervoj_v_mire_stranoj_gde_zapretili_solntsezaschitnye_kremy-500466/',
#  'https://tvrain.ru/news/moskvich_vyigral_v_novogodnjuju_lotereju_milliard_rublej-500465/',
#  'https://tvrain.ru/news/lenturu_oshtrafovali_na_800_tysjach_rublej_za_statju_o_legalizatsii_marihuany_v_evrope-500464/',
#  'https://tvrain.ru/news/vo_vladivostoke_v_novogodnjuju_noch_sozhgli_figuru_myshi_za_677_tysjach_rublej-500463/',
#  'https://tvrain.ru/teleshow/video/v_rossii_snizilsja_besposhlinnyj-500462/',
#  'https://tvrain.ru/news/tramp_predpolozhil_chto_rozhdestvenskij_podarok_kim_chen_yna_krasivaja_vaza_tot_objavil_o_novom_strategicheskom_oruzhii-500461/',
#  'https://tvrain.ru/teleshow/video/v_rossii_s_1_janvarja-500460/',
#  'https://tvrain.ru/teleshow/videooftheday/papa_rimskij_shlepnul-500459/',
#  'https://tvrain.ru/news/rossija_24_i_pervyj_kanal_skryli_schetchik_dizlajkov_pod_novogodnim_obrascheniem_putina_na_youtube-500458/',
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>Телеканал Дождь</title>
# <meta content="Телеканал ДОЖДЬ" property="og:title"/>
# <meta content="Телеканал для тех, кому не все равно" property="og:description"/>
# <meta content="http://tvrain.ru/static/css/pub/images/tvrain-logo-fb.png" property="og:image"/>
# <meta content="tv_show" property="og:type"/>
# <meta content="188964134476198" property="fb:app_id"/>
# <meta content="https://tvrain.ru/archive/?search_teleshow_cat=&amp;search_year=2020&amp;search_month=1&amp;search_day=1&amp;query=&amp;page=1" property="og:url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@tvrain" name="twitter:site"/>
# <meta content="@tvrain" name="twitter:creator"/>
# ...

# %%
for k, v in tvrain_20.items():
    print(k, len(v))
# Out:
# 2020.01.01 10
# 2020.01.02 20
# 2020.01.03 16
# 2020.01.04 10
# 2020.01.05 10
# 2020.01.06 20
# 2020.01.07 18
# 2020.01.08 17
# 2020.01.09 40
# 2020.01.10 60
# 2020.01.11 30
# 2020.01.12 13
# 2020.01.13 28
# 2020.01.14 60
# 2020.01.15 64
# 2020.01.16 86
# 2020.01.17 70
# 2020.01.18 30
# 2020.01.19 15
# 2020.01.20 40
# 2020.01.21 66
# 2020.01.22 84
# 2020.01.23 70
# 2020.01.24 70
# 2020.01.25 30
# 2020.01.26 11
# 2020.01.27 16
# 2020.01.28 65
# 2020.01.29 70
# 2020.01.30 60
# 2020.01.31 68
# 2020.02.01 30
# 2020.02.02 14
# 2020.02.03 28
# 2020.02.04 62
# 2020.02.05 70
# 2020.02.06 70
# 2020.02.07 70
# 2020.02.08 30
# 2020.02.09 10
# 2020.02.10 40
# 2020.02.11 58
# 2020.02.12 63
# 2020.02.13 58
# 2020.02.14 70
# 2020.02.15 30
# 2020.02.16 15
# 2020.02.17 16
# 2020.02.18 57
# 2020.02.19 60
# 2020.02.20 63
# 2020.02.21 57
# 2020.02.22 10
# 2020.02.23 10
# 2020.02.24 30
# 2020.02.25 46
# 2020.02.26 54
# 2020.02.27 55
# 2020.02.28 88

# %%
for link in tvrain_20['2020.01.18']:
# link = 'https://tvrain.ru/teleshow/video/merija_moskvy_soglasovala_miting_protiv_izmenenija_konstitutsii-501217/'
    try:
        r = requests.get(link)
        soup = BS(r.text)

        ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', id='article_content_text').find_all('p') if 'донейт' not in p.text])]).replace('\xa0', ' ').replace('\n\n', ' ')
    except (AttributeError, IndexError):
        print(link)

# %%
tvrain_2020 = []
for date in tqdm_notebook(list(tvrain_20.keys())):
    for link in tqdm_notebook(tvrain_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            tvrain_2020.append({'Media':'tvrain.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', id='article_content_text').find_all('p') if 'донейт' not in p.text])]).replace('\xa0', ' ').replace('\n\n', ' '), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(tvrain_2020).to_csv('tvrain_2020.csv', encoding='utf-8')
pd.DataFrame(tvrain_2020).to_csv('tvrain_2020.csv', encoding='utf-8')
pd.DataFrame(tvrain_2020)
# Out:
# ...
# https://tvrain.ru/lite/teleshow/kino/podstava-500577/
# ...
# https://tvrain.ru/lite/teleshow/strashnye_skazki/skazki_chitka-500592/
# https://tvrain.ru/lite/teleshow/strashnye_skazki/pochemu_schastlivoe_rozhdestvo_dlja_nekotoryh_ne_nastupit_nikogda-500594/
# ...
# https://tvrain.ru/lite/teleshow/rossija_eto_evropa/strana_pobedivshego_feminizma-500869/
# ...
# https://tvrain.ru/lite/teleshow/psihologija_na_dozhde/lektsija_biznes_trenera-501022/
# ...
# https://tvrain.ru/lite/teleshow/partnership/predstavitel_amerikanskogo_universiteta_otvetit_na_voprosy_postupajuschih_v_moskve_i_peterburge-501270/
# ...
# https://tvrain.ru/lite/teleshow/nobel/andre_zhid-501389/
# ...
# https://tvrain.ru/lite/teleshow/lectures_on_the_rain/chto_ne_tak_so_srednej_shkoloj-501475/
# ...
# https://tvrain.ru/lite/teleshow/v_smysle/test_na_muzhika-501560/
# ...
# https://tvrain.ru/lite/teleshow/rossija_eto_evropa/prinuzhdenie_k_porjadku_kto_pomogaet_politsii_v_borbe_za_nravstvennost-501799/
# ...

# %% [markdown]
# ## Autonews

# %%
# link = 'https://www.autonews.ru/ajax/tags/?tag=%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D1%82%D0%B8&offsetrbc=0&offset=500&limit=500'
# r = requests.get(link)
# soup = BS(r.json()['html'])

dates = [(div.find('span', 'item-medium__date').text, div.find('a', 'item-medium__link')['href']) for div in soup.find_all('div', 'item-medium')]
dates
# Out:
# [('25 марта', 'https://www.rbc.ru/rbcfreenews/5e7ac2ec9a7947a267446aee'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e590f069a79474b5a059e0d'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e59063c9a79474594e4754d'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58fd4b9a79474155374f46'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58e4d89a7947320a60248a'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58d3e09a794728b19143c0'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58c8b79a794723b907e034'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58bba89a79471c3951ea5d'),
#  ('28 февраля', 'https://www.autonews.ru/news/5e58b5df9a79471b373908ac'),
#  ('27 февраля', 'https://www.autonews.ru/news/5e57e7b39a7947d0158f4038'),
#  ('27 февраля', 'https://www.autonews.ru/news/5e57e6a99a7947cefcd9da1c'),
#  ('27 февраля', 'https://www.autonews.ru/news/5e57da1c9a7947c84c8da0b3'),
#  ('27 февраля', 'https://www.autonews.ru/news/5e57ce3f9a7947c0f14c1ecd'),
# ...

# %%
autonews_20 = defaultdict(list)
for i in dates[1:]:
    if 'января' in i[0]:
        date = '2020.01.'+i[0].split()[0]
    if 'февраля' in i[0]:
        date = '2020.02.'+i[0].split()[0]
    autonews_20[date].append(i[1])
autonews_20
# Out:
# defaultdict(list,
#             {'2020.02.28': ['https://www.autonews.ru/news/5e590f069a79474b5a059e0d',
#               'https://www.autonews.ru/news/5e59063c9a79474594e4754d',
#               'https://www.autonews.ru/news/5e58fd4b9a79474155374f46',
#               'https://www.autonews.ru/news/5e58e4d89a7947320a60248a',
#               'https://www.autonews.ru/news/5e58d3e09a794728b19143c0',
#               'https://www.autonews.ru/news/5e58c8b79a794723b907e034',
#               'https://www.autonews.ru/news/5e58bba89a79471c3951ea5d',
#               'https://www.autonews.ru/news/5e58b5df9a79471b373908ac'],
#              '2020.02.27': ['https://www.autonews.ru/news/5e57e7b39a7947d0158f4038',
#               'https://www.autonews.ru/news/5e57e6a99a7947cefcd9da1c',
#               'https://www.autonews.ru/news/5e57da1c9a7947c84c8da0b3',
#               'https://www.autonews.ru/news/5e57ce3f9a7947c0f14c1ecd',
#               'https://www.autonews.ru/news/5e57bdbe9a7947b7dfcb75b6',
# ...

# %%
for link in autonews_20['2020.02.14']:
    r = requests.get(link)
    soup = BS(r.text)
    ' '.join([soup.find('div', 'article__header__title').text, ' '.join([p.text for p in soup.find('div', 'article__text').find_all('p') if p.text]).replace('\xa0', ' ')])
# Out:
# Россия заняла 5-е место среди крупнейших авторынков Европы
# ...

# %%
autonews_2020 = []
for date in tqdm_notebook(sorted(list(autonews_20.keys()))):
    for link in tqdm_notebook(autonews_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            autonews_2020.append({'Media':'autonews.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.find('div', 'article__header__title').text, ' '.join([p.text for p in soup.find('div', 'article__text').find_all('p') if p.text]).replace('\xa0', ' ')]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(autonews_2020).to_csv('autonews_2020.csv', encoding='utf-8')
pd.DataFrame(autonews_2020).to_csv('autonews_2020.csv', encoding='utf-8')
pd.DataFrame(autonews_2020)
# Out:
# ...
#            Media        Date  \
# 0    autonews.ru  2020.01.10
# 1    autonews.ru  2020.01.10
# 2    autonews.ru  2020.01.10
# 3    autonews.ru  2020.01.10
# 4    autonews.ru  2020.01.10
# ..           ...         ...
# 494  autonews.ru   2020.02.7
# 495  autonews.ru   2020.02.7
# 496  autonews.ru   2020.02.7
# 497  autonews.ru   2020.02.7
# 498  autonews.ru   2020.02.7
#
#                                                   Link  \
# 0    https://www.autonews.ru/news/5e18a36a9a794736e...
# 1    https://www.autonews.ru/news/5e189f429a7947358...
# 2    https://www.autonews.ru/news/5e188fd69a79472e3...
# 3    https://www.autonews.ru/news/5e188a539a79472ba...
# 4    https://www.autonews.ru/news/5e18818c9a7947266...
# ..                                                 ...
# 494  https://www.autonews.ru/news/5e3d23c59a794730a...
# 495  https://www.autonews.ru/news/5e3d21fb9a79472fa...
# 496  https://www.autonews.ru/news/5e3d19749a79472b0...
# ...

# %% [markdown]
# ## N+1

# %%
texts = ['%D0%BE%D0%B1%D0%BD%D0%B0%D1%80%D1%83%D0%B6%D0%B8%D0%BB%D0%B8', # обнаружили
        '%D0%B8%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5', # исследование
        '%D1%81%D1%82%D0%B0%D1%82%D1%8C%D1%8F', # статья
         '%D0%B6%D1%83%D1%80%D0%BD%D0%B0%D0%BB%D0%B5', # журнале
#          '%D1%83%D1%87%D0%B5%D0%BD%D1%8B%D0%B5'] # ученые
         '%D0%BD%D0%B0%D1%88%D0%BB%D0%B8', # нашли
        ]
links = set()
for text in texts:
    link = f'https://nplus1.ru/search?q={text}'
    r = requests.get(link)
    soup = BS(r.text)
    links.update(['https://nplus1.ru'+a['href'] for a in soup.find('ol', 'list-search-results').find_all('a')
 if '2019' in a['href'] or '2020/01' in a['href'] or '2020/02' in a['href']])

# %%
len(links)
# Out:
# 1470

# %%
link = 'https://nplus1.ru/search?q=%D0%BE%D0%B1%D0%BD%D0%B0%D1%80%D1%83%D0%B6%D0%B8%D0%BB%D0%B8'
r = requests.get(link)
soup = BS(r.text)

# %%
['https://nplus1.ru'+a['href'] for a in soup.find('ol', 'list-search-results').find_all('a')
 if '2019' in a['href'] or '2020/01' in a['href'] or '2020/02' in a['href']]
# Out:
# ['https://nplus1.ru/news/2015/04/14/spanish-gominins',
#  'https://nplus1.ru/news/2016/05/19/martian-tsunami-waves',
#  'https://nplus1.ru/news/2016/05/24/two-new-craters',
#  'https://nplus1.ru/news/2016/08/11/serbia-magic-spell',
#  'https://nplus1.ru/news/2016/09/06/second-tabby',
#  'https://nplus1.ru/news/2016/07/16/ducklings-thinking',
#  'https://nplus1.ru/news/2016/08/30/blazar-i-choose-you',
#  'https://nplus1.ru/news/2019/01/24/calcium-carbonate-hemihydrate',
#  'https://nplus1.ru/news/2016/09/30/star-has-two-arms',
#  'https://nplus1.ru/news/2016/02/09/synechocystis',
#  'https://nplus1.ru/news/2016/03/14/Teyujagua-paradoxa',
#  'https://nplus1.ru/news/2017/09/22/snoozing-jellyfish',
#  'https://nplus1.ru/news/2019/09/21/congo-superbug',
#  'https://nplus1.ru/news/2015/04/08/scythian-treasure',
#  'https://nplus1.ru/news/2015/04/09/mummies',
#  'https://nplus1.ru/news/2015/04/09/spooning-skeletons',
#  'https://nplus1.ru/news/2018/03/31/old-relics-china',
# ...

# %%
for link in links:
    if '2020' in link:
        date = link[link.index('/2020/')+1:link.index('/2020/')+11].replace('/', '.')
    if '2019' in link:
        date = link[link.index('/2019/')+1:link.index('/2019/')+11].replace('/', '.')

# %%
link = 'https://nplus1.ru/news/2015/06/25/roman-shipwreck'
r = requests.get(link)
soup = BS(r.text)

# %%
'. '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'body js-mediator-article').find_all('p') if p.text and 'class' not in p.attrs]).replace('\xa0', ' ')])
# Out:
# 'В Средиземном море найден затонувший корабль возрастом 2000 лет. Итальянские водолазы обнаружили древнеримский корабль, затонувший около 2000 лет назад в проливе Бонифачо между островами Сардиния и Корсика. Судно перевозило груз терракотовой черепицы, вероятно, произведенной неподалеку от Рима. Об открытии сообщает The Telegraph. Место крушения было найдено в результате совместной операции итальянской полиции и археологов. По словам археологов, и сам корабль и его груз хорошо сохранились. Трюм корабля размером 20×8 квадратных метров был полностью заполнен плитками черепицы.  Авторы открытия предполагают, что корабль следовал или в Испанию, или к западному побережью Сардинии. Его груз мог предназначаться для строительства виллы богатого чиновника или торговца.  Ученые отмечают, что слишком большой вес черепицы мог в итоге стать одной из причин кораблекрушения. Для археологов эта находка может стать важным источником информации о торговле в древнем Риме. Полиция же в настоящее время о
# ...

# %%
soup.div.attrs
# Out:
# {'class': ['thx-rospechat']}

# %%
nplus1_19_20 = []
for link in tqdm_notebook(links):
#         if link not in pd.DataFrame(echo_2020).Link:
    if '2020' in link:
        date = link[link.index('/2020/')+1:link.index('/2020/')+11].replace('/', '.')
    if '2019' in link:
        date = link[link.index('/2019/')+1:link.index('/2019/')+11].replace('/', '.')    
    try:
        r = requests.get(link)
        soup = BS(r.text)
        nplus1_19_20.append({'Media':'nplus1.ru', 'Date':date, 'Link':link,
                              'Text':'. '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'body js-mediator-article').find_all('p') if p.text and 'class' not in p.attrs]).replace('\xa0', ' ')]), 
                              'Dep':'', 'Tags':[]})
    except (requests.exceptions.ConnectionError, AttributeError, 
            IndexError, requests.exceptions.TooManyRedirects, ValueError):
        print(link)
if date.endswith('1'):
    pd.DataFrame(nplus1_19_20).to_csv('nplus1_19_20.csv', encoding='utf-8')
pd.DataFrame(nplus1_19_20).to_csv('nplus1_19_20.csv', encoding='utf-8')
pd.DataFrame(nplus1_19_20)
# Out:
# ...
#           Media        Date  \
# 0     nplus1.ru  2019.05.31
# 1     nplus1.ru  2019.08.30
# 2     nplus1.ru  2019.03.05
# 3     nplus1.ru  2019.11.18
# 4     nplus1.ru  2019.10.24
# ...         ...         ...
# 1465  nplus1.ru  2019.04.10
# 1466  nplus1.ru  2019.01.25
# 1467  nplus1.ru  2019.02.02
# 1468  nplus1.ru  2019.04.29
# 1469  nplus1.ru  2019.10.17
#
#                                                    Link  \
# 0     https://nplus1.ru/news/2019/05/31/fungusvsmalaria
# 1     https://nplus1.ru/news/2019/08/30/organoidslik...
# 2     https://nplus1.ru/news/2019/03/05/solar-system...
# 3        https://nplus1.ru/news/2019/11/18/social-crows
# 4     https://nplus1.ru/news/2019/10/24/rareearth-se...
# ...                                                 ...
# 1465  https://nplus1.ru/news/2019/04/10/Homo-luzonensis
# 1466  https://nplus1.ru/news/2019/01/25/ebov-in-liberia
# 1467  https://nplus1.ru/news/2019/02/02/crispr-again...
# ...

# %%
nplus1_19_20 = pd.DataFrame(nplus1_19_20).sort_values(by='Date').reset_index().drop(['index'], axis = 1)
nplus1_19_20.to_csv('nplus1_19_20_order.csv', encoding='utf-8')

# %% [markdown]
# ## Постанука

# %%
link = 'https://postnauka.ru/api/v4/grid?page=4'
r = requests.get(link)
for link in ['https://postnauka.ru'+i['url'] for i in r.json() if 'courses' not in i['url']]:
    r = requests.get(link)
    soup = BS(r.text)
    print(link)
    print(' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'article-text').find_all('p')])]).replace('\xa0', ' ').replace('\n', ' '))
# Out:
# https://postnauka.ru/video/154860
# ...

# %%
months_names = {'Января':'01', 'Февраля':'02', 'Марта':'03', 'Апреля':'04', 
                'Мая':'05', 'Июня':'06', 'Июля':'07', 'Августа':'08', 
                'Сентября':'09', 'Октября':'10', 'Ноября':'11', 'Декабря':'12'}
postnauka_19_20 = []
for page in tqdm_notebook(range(151)):
    url = f'https://postnauka.ru/api/v4/grid?page={page+1}'
    r = requests.get(url)
    for link in tqdm_notebook(['https://postnauka.ru'+i['url'] for i in r.json() if 'courses' not in i['url']]):
        try:
            r = requests.get(link)
            soup = BS(r.text)
            date = soup.find('div', 'pub-data-item').text
            if '2019' in date or ('2020' in date and 
                              (months_names[date.split()[1]]=='01' or months_names[date.split()[1]]=='02')):
                postnauka_19_20.append({'Media':'postnauka.ru', 'Date':f'{date.split()[2]}.{months_names[date.split()[1]]}.{date.split()[0]}', 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'article-text').find_all('p')])]).replace('\xa0', ' ').replace('\n', ' '), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(postnauka_19_20).to_csv('postnauka_19_20.csv', encoding='utf-8')
pd.DataFrame(postnauka_19_20).to_csv('postnauka_19_20.csv', encoding='utf-8')
pd.DataFrame(postnauka_19_20)
# Out:
# ...
# https://postnauka.ru/longreads/29279
# ...
# https://postnauka.ru/longreads/88812
# https://postnauka.ru/longreads/154811
# ...
# https://postnauka.ru/longreads/88742
# ...
# https://postnauka.ru/longreads/88742
# https://postnauka.ru/longreads/88757
# https://postnauka.ru/tests/62411
# ...
# https://postnauka.ru/longreads/154995
# https://postnauka.ru/longreads/88767
# https://postnauka.ru/longreads/88733
# ...
# https://postnauka.ru/tests/79475
# ...
# https://postnauka.ru/tests/154390
# https://postnauka.ru/longreads/86459
# https://postnauka.ru/tests/155071
# https://postnauka.ru/longreads/88750
# ...
# https://postnauka.ru/longreads/88750
# https://postnauka.ru/longreads/82190
# https://postnauka.ru/longreads/100593
# ...
# https://postnauka.ru/longreads/96369
# ...
# https://postnauka.ru/tests/154967
# https://postnauka.ru/tests/60516
# https://postnauka.ru/tests/64360
# https://postnauka.ru/longreads/89794
# ...
# https://postnauka.ru/longreads/88776
# ...
# https://postnauka.ru/tests/93338
# https://postnauka.ru/longreads/82325
# ...

# %%
pd.DataFrame(postnauka_19_20)[pd.DataFrame(postnauka_19_20).Date=='2019.02.06']
# Out:
#             Media        Date                              Link  \
# 61   postnauka.ru  2019.02.06    https://postnauka.ru/faq/94722
# 217  postnauka.ru  2019.02.06  https://postnauka.ru/video/95142
#
#                                                   Text Dep Tags
# 61   Иврит: история, письменность и современное сос...       []
# 217  Рабы и бастарды   Владимир Святославович свата...       []

# %%
# postnauka_19_20 = pd.DataFrame(postnauka_19_20).sort_values(by='Date').reset_index().drop(['index'], axis = 1)
postnauka_19_20.to_csv('postnauka_19_20_order.csv', encoding='utf-8')

# %%
months_names = {'Января':'01', 'Февраля':'02', 'Марта':'03', 'Апреля':'04', 
                'Мая':'05', 'Июня':'06', 'Июля':'07', 'Августа':'08', 
                'Сентября':'09', 'Октября':'10', 'Ноября':'11', 'Декабря':'12'}
for page in range(151):
    url = f'https://postnauka.ru/api/v4/grid?page={page+1}'
    r = requests.get(url)
    for link in ['https://postnauka.ru'+i['url'] for i in r.json() if 'courses' not in i['url']]:
        r = requests.get(link)
        soup = BS(r.text)
        date = soup.find('div', 'pub-data-item').text
        if '2019' in date or ('2020' in date and 
                              (months_names[date.split()[1]]=='01' or months_names[date.split()[1]]=='02')):
            print(f'{date.split()[2]}.{months_names[date.split()[1]]}.{date.split()[0]}')
# Out:
# 2019.04.27
# 2019.02.25
# 2019.11.26
# 2019.04.18

# %%
url = 'https://postnauka.ru/api/v4/grid?page=1'
r = requests.get(url)
r.json()
# Out:
# [{'id': 155103,
#   'title': 'Марк Симон: «Поп-музыка — это мощный инструмент коллективного воображения»',
#   'description': 'О полевых записях ранних этномузыковедов, повороте к идентичности в исследованиях популярной музыки и социологии маргинальности',
#   'url': '/talks/155103',
#   'is_adv': 0,
#   'count_hits': 0,
#   'promo_shows': 0,
#   'status': 100,
#   'is_main': 1,
#   'card_type': 'text',
#   'type': 'post',
#   'replace_tag_with': None,
#   'itemsCount': 0,
#   'image': {'id': 71141,
#    'type': 'image',
#    'description': ' giphy.com',
#    'copyright': ' ',
#    'sizes': {'full': '/files/images/7/1/1/4/1/0/0/0/0/0/S_PRFVeGVsto1RD5XRygmAmIX6XufVIQ.gif',
#     'thumb': '/files/images/7/1/1/4/1/0/0/0/0/0/thumb/S_PRFVeGVsto1RD5XRygmAmIX6XufVIQ.gif'}},
#   'icon': None,
#   'statistics': {'videoPlays': 16593,
#    'videoLength': '14:05',
#    'pageShares': 22,
#    'pageViews': 778,
#    'threeDaysViews': 188},
#   'subtitle': None,
#   'themes': [{'alias': 'culture',
# ...

# %% [markdown]
# ## Indicator

# %%
links = defaultdict(list)
rubrics = ['astronomy', 'biology', 'humanitarian-science', 'mathematics', 'earth-science',
          'agriculture', 'medicine', 'engineering-science', 'physics', 'chemistry-and-materials']
for rubric in tqdm_notebook(rubrics):
    link = f'https://indicator.ru/api/v2/topics?include=image&limit=100&offset=0&rubric_root={rubric}&topic_type=-daily_photo%2Cevent&with_filtered_count=1'
    r = requests.get(link)
    print(rubric, r.json()['meta']['filtered_count'], '\n')
    num_of_pages = ceil(r.json()['meta']['filtered_count']/100)
    for i in tqdm_notebook(range(num_of_pages)):
        link = f'https://indicator.ru/api/v2/topics?include=image&limit=100&offset={i*100}&rubric_root={rubric}&topic_type=-daily_photo%2Cevent&with_filtered_count=1'
        r = requests.get(link)
        for item in r.json()['data']:
            date = item['attributes']['published_at'][:10]
            if '2019' in date or '2020-01' in date or '2020-02' in date:
#                 print(date.replace('-', '.'), )
                links[date.replace('-', '.')].append('https://indicator.ru'+item['attributes']['link'])
    print(len(links))
# Out:
# ...
# astronomy 1586
# ...
# 230
# biology 2747
# ...
# 389
# humanitarian-science 2113
# ...
# 417
# mathematics 747
# ...
# 422
# earth-science 852
# ...
# 424
# agriculture 309
# ...
# 424
# medicine 2430
# ...
# 425
# engineering-science 2022
# ...
# 425
# physics 1379
# ...
# 425
# chemistry-and-materials 1276
# ...
# 425

# %%
i = 1
rubric = 'medicine'
link = f'https://indicator.ru/api/v2/topics?include=image&limit=100&offset=0&rubric_root={rubric}&topic_type=-daily_photo%2Cevent&with_filtered_count=1'
r = requests.get(link)
[item['attributes']['published_at'] for item in r.json()['data']]
# Out:
# ['2020-05-05T11:36:21.000Z',
#  '2020-05-05T07:44:00.000Z',
#  '2020-05-04T13:24:05.000Z',
#  '2020-05-03T08:21:02.000Z',
#  '2020-05-02T10:01:45.000Z',
#  '2020-05-01T20:10:53.000Z',
#  '2020-05-01T10:23:20.000Z',
#  '2020-05-01T08:06:07.000Z',
#  '2020-04-30T20:17:21.000Z',
#  '2020-04-30T14:07:17.000Z',
#  '2020-04-30T10:49:12.000Z',
#  '2020-04-30T08:12:02.000Z',
#  '2020-04-30T06:09:02.000Z',
#  '2020-04-29T21:07:01.000Z',
#  '2020-04-29T16:39:43.000Z',
#  '2020-04-29T08:47:16.000Z',
#  '2020-04-28T20:51:38.000Z',
#  '2020-04-28T11:23:03.000Z',
#  '2020-04-28T08:00:50.000Z',
#  '2020-04-27T20:13:54.000Z',
#  '2020-04-27T15:21:51.000Z',
#  '2020-04-27T14:07:25.000Z',
#  '2020-04-27T08:25:42.000Z',
#  '2020-04-26T10:16:32.000Z',
#  '2020-04-25T17:43:53.000Z',
#  '2020-04-25T11:56:09.000Z',
#  '2020-04-25T09:52:50.000Z',
#  '2020-04-24T20:29:07.000Z',
#  '2020-04-24T18:00:33.000Z',
#  '2020-04-24T14:07:43.000Z',
#  '2020-04-24T11:14:50.000Z',
#  '2020-04-24T08:19:05.000Z',
# ...

# %%
sorted(dict(links).keys())
# Out:
# ['2019.01.01',
#  '2019.01.02',
#  '2019.01.03',
#  '2019.01.04',
#  '2019.01.05',
#  '2019.01.06',
#  '2019.01.07',
#  '2019.01.08',
#  '2019.01.09',
#  '2019.01.10',
#  '2019.01.11',
#  '2019.01.12',
#  '2019.01.13',
#  '2019.01.14',
#  '2019.01.15',
#  '2019.01.16',
#  '2019.01.17',
#  '2019.01.18',
#  '2019.01.19',
#  '2019.01.20',
#  '2019.01.21',
#  '2019.01.22',
#  '2019.01.23',
#  '2019.01.24',
#  '2019.01.25',
#  '2019.01.26',
#  '2019.01.27',
#  '2019.01.28',
#  '2019.01.29',
#  '2019.01.30',
#  '2019.01.31',
#  '2019.02.01',
#  '2019.02.02',
#  '2019.02.03',
#  '2019.02.04',
#  '2019.02.05',
#  '2019.02.06',
#  '2019.02.07',
#  '2019.02.08',
#  '2019.02.09',
#  '2019.02.10',
#  '2019.02.11',
#  '2019.02.12',
#  '2019.02.13',
#  '2019.02.14',
#  '2019.02.15',
#  '2019.02.16',
#  '2019.02.17',
#  '2019.02.18',
#  '2019.02.19',
#  '2019.02.20',
#  '2019.02.21',
#  '2019.02.22',
#  '2019.02.23',
#  '2019.02.24',
#  '2019.02.25',
#  '2019.02.26',
#  '2019.02.27',
# ...

# %%
r.json()['data'][0]['attributes']['published_at'][:10]
# Out:
# '2016-10-26'

# %%
'https://indicator.ru'+r.json()['data'][0]['attributes']['link']
# Out:
# 'https://indicator.ru/chemistry-and-materials/klassificirovali-rastvoriteli-perovskitnykh-solnechnykh-batarei-05-05-2020.htm'

# %%
links_indicator_19_20 = defaultdict(list)
links_without_date = []
for link in links:
    if link.endswith('2019.htm') or link.endswith('01-2020.htm') or link.endswith('02-2020.htm'):
        date = link[-14:-4].split('-')
        date = f'{date[2]}.{date[1]}.{date[0]}'
        links_indicator_19_20[date].append(link)
    if not (link.endswith('2020.htm') or link.endswith('2019.htm') or link.endswith('2018.htm')
           or link.endswith('2017.htm') or link.endswith('2016.htm')):
        links_without_date.append(link)

# %%
link = 'https://indicator.ru/physics/kubitov-parnye-kvantovye-tochki-31-01-2020.htm'
date = link[-14:-4].split('-')
date = f'{date[2]}.{date[1]}.{date[0]}'
date
# Out:
# '2020.01.31'

# %%
len(links_indicator_19_20), len(links_without_date)
# Out:
# (425, 2771)

# %%
for k, v in sorted(links_indicator_19_20.items()):
    print(k, len(v))
# Out:
# 2019.01.01 3
# 2019.01.02 5
# 2019.01.03 5
# 2019.01.04 6
# 2019.01.05 5
# 2019.01.06 5
# 2019.01.07 5
# 2019.01.08 5
# 2019.01.09 6
# 2019.01.10 8
# 2019.01.11 7
# 2019.01.12 5
# 2019.01.13 5
# 2019.01.14 8
# 2019.01.15 9
# 2019.01.16 8
# 2019.01.17 8
# 2019.01.18 7
# 2019.01.19 5
# 2019.01.20 5
# 2019.01.21 8
# 2019.01.22 8
# 2019.01.23 8
# 2019.01.24 10
# 2019.01.25 8
# 2019.01.26 5
# 2019.01.27 5
# 2019.01.28 8
# 2019.01.29 8
# 2019.01.30 9
# 2019.01.31 8
# 2019.02.01 8
# 2019.02.02 5
# 2019.02.03 5
# 2019.02.04 10
# 2019.02.05 8
# 2019.02.06 9
# 2019.02.07 8
# 2019.02.08 8
# 2019.02.09 6
# 2019.02.10 5
# 2019.02.11 8
# 2019.02.12 7
# 2019.02.13 7
# 2019.02.14 8
# 2019.02.15 8
# 2019.02.16 6
# 2019.02.17 4
# 2019.02.18 7
# 2019.02.19 8
# 2019.02.20 8
# 2019.02.21 7
# 2019.02.22 9
# 2019.02.23 5
# 2019.02.24 5
# 2019.02.25 7
# 2019.02.26 8
# 2019.02.27 8
# 2019.02.28 9
# 2019.03.01 8
# 2019.03.02 6
# 2019.03.03 5
# 2019.03.04 9
# 2019.03.05 9
# 2019.03.06 8
# 2019.03.07 8
# ...

# %%
for link in links_without_date:
    r = requests.get
# Out:
# ['https://indicator.ru/astronomy/chto-novogo-v-nature-i-science-3-maya.htm',
#  'https://indicator.ru/astronomy/chto-novogo-v-nature-i-science-26-aprelya.htm',
#  'https://indicator.ru/astronomy/temnye-vremena.htm',
#  'https://indicator.ru/astronomy/chto-novogo-nature-science-lancet-30-marta.htm',
#  'https://indicator.ru/astronomy/daidzhest-nauchno-populyarnykh-onlain-meropriyatii-30-03-05-04.htm',
#  'https://indicator.ru/astronomy/osvoenie-kosmosa-dalneishei-zhizni-cheloveka.htm',
#  'https://indicator.ru/astronomy/daidzhest-nauchno-populyarnykh-meropriyatii-16-03-22-03.htm',
#  'https://indicator.ru/astronomy/chto-novogo-v-nature-science-1-marta.htm',
#  'https://indicator.ru/astronomy/chto-novogo-v-nature-science-i-the-lancet-24-fevralya.htm',
#  'https://indicator.ru/astronomy/daidzhest-nauchno-populyarnykh-meropriyatii-10-02-16-02.htm',
#  'https://indicator.ru/astronomy/proshanie-s-velikoi-observatoriei.htm',
# ...

# %%
for k, v in sorted(links.items()):
    print(k, len(v))
# Out:
# 2019.01.01 4
# 2019.01.02 6
# 2019.01.03 6
# 2019.01.04 7
# 2019.01.05 6
# 2019.01.06 6
# 2019.01.07 6
# 2019.01.08 6
# 2019.01.09 7
# 2019.01.10 9
# 2019.01.11 8
# 2019.01.12 6
# 2019.01.13 6
# 2019.01.14 10
# 2019.01.15 10
# 2019.01.16 9
# 2019.01.17 9
# 2019.01.18 9
# 2019.01.19 6
# 2019.01.20 6
# 2019.01.21 10
# 2019.01.22 9
# 2019.01.23 9
# 2019.01.24 11
# 2019.01.25 9
# 2019.01.26 6
# 2019.01.27 6
# 2019.01.28 10
# 2019.01.29 10
# 2019.01.30 10
# 2019.01.31 9
# 2019.02.01 9
# 2019.02.02 6
# 2019.02.03 6
# 2019.02.04 12
# 2019.02.05 9
# 2019.02.06 10
# 2019.02.07 9
# 2019.02.08 9
# 2019.02.09 7
# 2019.02.10 6
# 2019.02.11 10
# 2019.02.12 8
# 2019.02.13 8
# 2019.02.14 10
# 2019.02.15 9
# 2019.02.16 7
# 2019.02.17 5
# 2019.02.18 9
# 2019.02.19 9
# 2019.02.20 9
# 2019.02.21 8
# 2019.02.22 10
# 2019.02.23 6
# 2019.02.24 6
# 2019.02.25 9
# 2019.02.26 9
# 2019.02.27 10
# 2019.02.28 10
# 2019.03.01 9
# 2019.03.02 7
# 2019.03.03 6
# 2019.03.04 11
# 2019.03.05 10
# 2019.03.06 9
# ...

# %%
with open('indicator_links_19_20.json', 'w', encoding = 'utf-8') as f:
    json.dump(links, f)

# %%
links['2020.01.19']
# Out:
# ['https://indicator.ru/astronomy/luchshee-za-den-19-yanvarya-20-01-2020.htm',
#  'https://indicator.ru/astronomy/chto-novogo-v-nature-i-science-19-yanvarya.htm',
#  'https://indicator.ru/astronomy/spacex-uspeshno-ispytala-sistemu-spaseniya-pilotiruemogo-korablya-19-01-2020.htm',
#  'https://indicator.ru/biology/uchenye-prosledili-za-kannibalizmom-u-bakterii-19-01-2020.htm',
#  'https://indicator.ru/biology/fotosinteziruyushie-mikroorganizmy-pomogut-gorodu-ochistit-vodu-19-01-2020.htm',
#  'https://indicator.ru/chemistry-and-materials/issledovateli-nauchili-neiroset-prinimat-vo-vnimanie-khimicheskie-uravneniya-dlya-sozdaniya-novykh-lekarstv-i-materialov-19-01-2020.htm']

# %%
link = 'https://indicator.ru/astronomy/spacex-uspeshno-ispytala-sistemu-spaseniya-pilotiruemogo-korablya-19-01-2020.htm'
soup = BS(requests.get(link).text)

# %%
' .'.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'text').find_all('p') 
                                   if 'Мои источники' not in p.text and 'Подписывайтесь на Indicator.Ru в соцсетях' not in p.text])])
# Out:
# 'SpaceX  успешно испытала систему спасения пилотируемого корабля .Сегодня компания SpaceX провела успешные испытания системы спасения космического пилотируемого корабля Crew Dragon.  NASA сообщает, что после запуска ракеты Falcon 9 корабль успешно отвели от ракеты на безопасное расстояние двигатели системы аварийного спасения SuperDraco, а сама ракета взорвалась.  В корабле находились два манекена с датчиками, которые измеряли воздействие, оказанное на потенциальных астронавтов. После раскрытия парашютов Crew Dragon благополучно приводнился в океане. Сейчас команда SpaceX изучает вернувшийся на Землю аппарат и готовит его к следующему полету. Полет корабля с экипажем может состояться уже в марте-мае.'

# %%
indicator_19_20 = []
for date in tqdm_notebook(sorted(list(links.keys()))):
    for link in tqdm_notebook(links[date]):
        time.sleep(1)
        try:
            r = requests.get(link)
            soup = BS(r.text)
            indicator_19_20.append({'Media':'indicator.ru', 'Date':date, 'Link':link,
                                  'Text':' .'.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'text').find_all('p') 
                                   if 'Мои источники' not in p.text and 'Подписывайтесь на Indicator.Ru в соцсетях' not in p.text])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(indicator_19_20).to_csv('indicator_19_20.csv', encoding='utf-8')
pd.DataFrame(indicator_19_20).to_csv('indicator_19_20.csv', encoding='utf-8')
pd.DataFrame(indicator_19_20)
# Out:
# ...
# https://indicator.ru/earth-science/ne-gruzi-prirodu.htm
# https://indicator.ru/medicine/rezhim-pitaniya.htm
# https://indicator.ru/medicine/bolshie-vyzovy-starenie-naseleniya-i-novye-bolezni.htm
# ...
# https://indicator.ru/earth-science/kak-nam-osvoit-rossiyu.htm
# ...
# https://indicator.ru/mathematics/progress-v-zashite.htm
# ...
# https://indicator.ru/chemistry-and-materials/krov-ekonomiki.htm
# ...
# https://indicator.ru/engineering-science/tekhnologicheskii-perevorot.htm
# ...
#              Media        Date  \
# 0     indicator.ru  2019.01.01
# 1     indicator.ru  2019.01.01
# 2     indicator.ru  2019.01.01
# 3     indicator.ru  2019.01.01
# 4     indicator.ru  2019.01.02
# ...            ...         ...
# 3794  indicator.ru  2020.02.29
# 3795  indicator.ru  2020.02.29
# 3796  indicator.ru  2020.02.29
# 3797  indicator.ru  2020.02.29
# 3798  indicator.ru  2020.02.29
#
#                                                    Link  \
# 0        https://indicator.ru/astronomy/ultima-tule.htm
# ...

# %% [markdown]
# ## Mediazona

# %%
# links = set()
for text in tqdm_notebook([
#     '%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BB', 
                           '%D0%B3%D0%BE%D0%B2%D0%BE%D1%80%D0%B8%D1%82',
                          '%D1%81%D1%87%D0%B8%D1%82%D0%B0%D0%B5%D1%82', '%D1%80%D0%B0%D1%81%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BB',
                          '%D0%BD%D0%B0%D0%BF%D0%B8%D1%81%D0%B0%D0%BB', '%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB',
                          '%D0%BE%D0%B1%D1%8A%D1%8F%D1%81%D0%BD%D0%B8%D0%BB', '%D0%BF%D1%80%D0%B8%D1%88%D0%BB%D0%B8']):
    page = 1
    while True:
        time.sleep(0.5)
        link = f'https://zona.media/search?q={text}&page={page}'
        soup = BS(requests.get(link).text)
        links_temp = ['https://zona.media'+li.find('a')['href'] for li in soup.find_all('li', 'mz-search-result__item')]
        links.update(links_temp)
        print(page, len(links_temp), len(links))
        if links_temp and '/2018/' not in links_temp[-1]:
            page += 1
        else:
            break
            
with open('mediazona_links.json', 'w', encoding = 'utf-8') as f:
    json.dump({'data':list(links)}, f)
# Out:
# ...
# 1 30 3467
# 2 30 3486
# 3 30 3501
# 4 30 3515
# 5 30 3530
# 6 30 3547
# 7 30 3568
# 8 30 3580
# 9 30 3597
# 10 30 3608
# 11 30 3621
# 12 30 3635
# 13 30 3648
# 14 30 3660
# 15 30 3671
# 16 30 3687
# 17 30 3701
# 18 30 3720
# 19 30 3731
# 20 30 3741
# 21 30 3752
# 22 30 3767
# 23 30 3776
# 24 30 3789
# 25 30 3809
# 26 30 3822
# 27 30 3834
# 28 30 3846
# 29 30 3865
# 30 30 3880
# 31 30 3892
# 32 30 3905
# 33 30 3919
# 34 30 3931
# 35 30 3941
# 36 30 3956
# 37 30 3970
# 38 30 3981
# 39 30 3992
# 40 30 4004
# 41 30 4022
# 42 30 4035
# 43 30 4052
# 44 30 4064
# 45 30 4083
# 46 30 4095
# 47 30 4110
# 48 30 4126
# 49 30 4142
# 50 30 4155
# 51 30 4163
# 52 30 4174
# 53 30 4185
# 54 30 4196
# 55 30 4207
# 56 30 4222
# 57 30 4231
# 58 30 4240
# 59 30 4255
# 60 30 4266
# 61 30 4275
# 62 30 4284
# 63 30 4298
# 64 30 4312
# 65 30 4325
# 66 30 4338
# 67 30 4351
# 68 30 4364
# 69 30 4376
# 70 30 4389
# 71 30 4402
# 72 30 4415
# 73 30 4427
# 74 30 4441
# 75 30 4456
# 76 30 4470
# 77 30 4483
# ...

# %%
link = 'https://zona.media/search?q=%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BB&page=181'
soup = BS(requests.get(link).text)

# %%
['https://zona.media'+li.find('a')['href'] for li in soup.find_all('li', 'mz-search-result__item')]
# Out:
# ['https://zona.media/news/2018/03/07/komissiya',
#  'https://zona.media/news/2018/03/07/dagestan',
#  'https://zona.media/news/2018/03/07/do-not-look',
#  'https://zona.media/news/2018/03/07/yaroslavl',
#  'https://zona.media/news/2018/03/07/cit',
#  'https://zona.media/news/2018/03/07/pupki',
#  'https://zona.media/news/2018/03/07/dukova-sogl',
#  'https://zona.media/article/2018/03/07/batrayev',
#  'https://zona.media/news/2018/03/07/rostov-vzryv',
#  'https://zona.media/article/2018/03/07/bravenewface',
#  'https://zona.media/news/2018/03/07/kluchev-video',
#  'https://zona.media/news/2018/03/07/rubka-gosdep',
#  'https://zona.media/news/2018/03/06/rosavia',
#  'https://zona.media/news/2018/03/06/farida',
#  'https://zona.media/news/2018/03/06/kinzhal',
#  'https://zona.media/news/2018/03/06/fatigue',
#  'https://zona.media/news/2018/03/06/voronezh',
#  'https://zona.media/news/2018/03/06/tally',
#  'https://zona.media/news/2018/03/06/dp',
# ...

# %%
with open('mediazona_links.json') as f:
    mediazona_links = json.load(f)

# %%
mediazona_links['data']
# Out:
# ['https://zona.media/news/2019/08/12/sosnovskaja-sk',
#  'https://zona.media/news/2020/03/04/break',
#  'https://zona.media/online/2019/10/11/benyash-25',
#  'https://zona.media/news/2019/03/19/krupenia',
#  'https://zona.media/news/2019/10/11/prm',
#  'https://zona.media/news/2019/03/04/shvabra',
#  'https://zona.media/news/2019/03/11/block',
#  'https://zona.media/news/2019/03/01/pochti-god',
#  'https://zona.media/news/2020/04/06/dag',
#  'https://zona.media/news/2020/01/04/fedorov-miting',
#  'https://zona.media/news/2019/09/05/fomin',
#  'https://zona.media/news/2019/03/27/belov-free',
#  'https://zona.media/news/2019/10/14/nn',
#  'https://zona.media/news/2020/04/03/pkrvskbln',
#  'https://zona.media/news/2019/11/19/stakhovtsev',
#  'https://zona.media/news/2019/07/18/snob',
#  'https://zona.media/online/2019/12/17/surovtsev',
#  'https://zona.media/news/2019/04/04/udalili',
#  'https://zona.media/news/2019/09/06/beglov-flat',
#  'https://zona.media/news/2019/11/06/otpustili',
# ...

# %%
links = defaultdict(list)
for link in tqdm_notebook(mediazona_links['data']):
    if '/2020/' in link:
        date = link[link.index('2020/'):link.index('2020/')+10].replace('/', '.')
    if '/2019/' in link:
        date = link[link.index('2019/'):link.index('2019/')+10].replace('/', '.')
    links[date].append(link)

# %%
links = dict(links)

# %%
mediazona_19_20 = []
for date in tqdm_notebook(sorted(list(links.keys()))):
    for link in tqdm_notebook(links[date]):
        try:
            r = requests.get(link)
            soup = BS(r.text)
            mediazona_19_20.append({'Media':'zona.media', 'Date':date, 'Link':link,
                                  'Text':'. '.join([soup.find('header', 'mz-publish__title').text, 
                                                    ' '.join([p.text for p in 
                                                              soup.find('section', 'mz-publish__text').find_all('p')])]).replace('\xa0', ' '), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(mediazona_19_20).to_csv('mediazona_19_20.csv', encoding='utf-8')
pd.DataFrame(mediazona_19_20).to_csv('mediazona_19_20.csv', encoding='utf-8')
pd.DataFrame(mediazona_19_20)
# Out:
# ...
# https://zona.media/chronicle/ekbprotest
# https://zona.media/chronicle/bulvar
# ...
# https://zona.media/chronicle/ik15
# ...
# https://zona.media/chronicle/magnitogorsk
# ...
# https://zona.media/chronicle/mucolgov-obysk
# ...
# https://zona.media/news/2019/01/14/mxt
# https://zona.media/online/2019/01/14/seventhstudio-16
# ...
# https://zona.media/chronicle/lub
# https://zona.media/online/2019/01/15/seventhstudio-17
# ...
# https://zona.media/chronicle/sakharova-ap
# https://zona.media/online/2019/01/16/seventhstudio-18
# https://zona.media/chronicle/police
# ...
# https://zona.media/online/2019/01/17/shishkin
# ...
# https://zona.media/online/2019/01/18/seventhstudio-19
# https://zona.media/number/2019/01/18/gas
# ...
# https://zona.media/online/2019/01/19/rybka-jail
# ...
# https://zona.media/chronicle/mosgorsearch
# ...
# https://zona.media/online/2019/01/22/surgut-moskva
# https://zona.media/chronicle/svtvbsk
# ...
# https://zona.media/chronicle/shahty
# https://zona.media/online/2019/01/23/seventhstudio-20
# ...

# %%
link = 'https://zona.media/news/2020/01/29/koronavirus'
r = requests.get(link)
soup = BS(r.text)

# %%
'. '.join([soup.find('header', 'mz-publish__title').text, ' '.join([p.text for p in soup.find('section', 'mz-publish__text').find_all('p')])]).replace('\xa0', ' ')
# Out:
# 'Россия ограничит железнодорожное сообщение с Китаем из‑за коронавируса. Россия с 31 января ограничит железнодорожное сообщение с Китаем из-за риска распространения коронавируса. Об этом сообщает ТАСС со ссылкой на вице-премьера Татьяну Голикову. «С четверга на пятницу ограничиваем железнодорожное движение. Поезда будут двигаться по маршруту Москва — Пекин и Пекин — Москва», — сказала она. Кроме того, Голикова сообщила, что российским вузам предложили до 1 марта продлить новогодние каникулы для студентов из Китая. Ранее пять регионов на Дальнем Востоке закрыли пункты пропуска на границе с Китаем. Срок их закрытия продлили до 1 марта. В конце декабря в китайском городе Ухань произошла вспышка нового типа коронавируса. На сегодняшний день известно о 5999 заболевших, из них 132 человека скончались, еще 104 пациента излечились. '

# %% [markdown]
# ## The Bell

# %%
link = 'https://thebell.io/wp-admin/admin-ajax.php'
# q = 'action=archive&page=8&count=20&type=category&id=news&lang=RU'
q = {'action':'archive', 'page':7, 'count':20, 'type':'category', 'id':'news', 'lang':'RU'}
r = requests.post(link, data=q)
soup = BS(r.text)

[a['href'] for a in soup.find_all('a', 'news-item__link')]
# Out:
# ['https://thebell.io/tatneft-rezko-snizila-dobychu-uzhe-v-aprele/',
#  'https://thebell.io/subsidii-ne-poluchat-kompanii-s-nalogovoj-zadolzhennostyu-svyshe-3-tysyach-rublej/',
#  'https://thebell.io/rejting-putina-v-aprele-postavil-novyj-antirekord/',
#  'https://thebell.io/rossiya-obognala-kitaj-po-kolichestvu-zarazhennyh-koronavirusom/',
#  'https://thebell.io/neft-padaet-pered-ispolneniem-majskih-fyuchersov-brent/',
#  'https://thebell.io/peskov-sprognoziroval-vyhod-na-plato-po-koronavirusu-k-seredine-maya/',
#  'https://thebell.io/pochti-polovina-rossiyan-ne-boyatsya-zarazitsya-koronavirusom/',
#  'https://thebell.io/mintrans-predlozhil-razreshit-transportnym-kompaniyam-vozvrashhat-dengi-za-bilety-vaucherami/',
#  'https://thebell.io/rejting-mishustina-na-postu-premera-okazalsya-ne-vyshe-chem-u-medvedeva/',
#  'https://thebell.io/koronavirus-daily-glavnoe-o-pandemii-k-26-aprelya/',
#  'https://thebell.io/dohody-rossiyan-upali-eshhe-do-nachala-krizisa/',
# ...

# %%
link = 'https://thebell.io/api/v1/layout_theme_data/?route=category&param=news&last_post_id=11061&index=7&count=3&lang=ru'
r = requests.get(link)
soup = BS(r.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="ru-RU" ng-app="thebell" ng-controller="MainController" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#  profile: http://ogp.me/ns/profile# fb: http://ogp.me/ns/fb#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, maximum-scale=1.0, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="@thebell_io" name="telegram:channel"/>
# <meta content="wUcLdNK4eUrkiPeuLoS6YuyeekaDknhFBQ6BfUU5Nxk" name="google-site-verification"/>
# <title>Страница не найдена — The Bell</title>
# <link href="https://thebell.io/wp-content/themes/thebell/images/icons/manifest.json" rel="manifest"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#fd371d" name="theme-color"/>
# <meta name="application-name"/>
# ...

# %%
link = 'https://thebell.io/category/news/page/99/'
r = requests.get(link)
soup = BS(r.text)

[(div.find('a', 'news-item__link')['href'], div.find('span', 'news-item__info').text) for div in 
 soup.find_all('div', 'news-item-row') if div.find('span')]
# Out:
# [('https://thebell.io/rospotrebnadzor-rekomendoval-vozderzhatsya-ot-poezdok-za-granitsu-iz-za-koronavirusa/',
#   '29 февраля 2020'),
#  ('https://thebell.io/tsena-nefti-probila-otmetku-v-49-za-barrel/',
#   '28 февраля 2020'),
#  ('https://thebell.io/rynki-v-ssha-otkrylis-novym-obvalom-rossijskie-indeksy-teryayut-5-6/',
#   '28 февраля 2020'),
#  ('https://thebell.io/yandeks-stal-skryvat-publikatsii-o-rodstvennike-premera-mishustina/',
#   '28 февраля 2020'),
#  ('https://thebell.io/zhenevskij-avtosalon-otmenen-iz-za-koronavirusa/',
#   '28 февраля 2020'),
#  ('https://thebell.io/koronavirus-ster-5-trln-mirovoj-kapitalizatsii/',
#   '28 февраля 2020'),
#  ('https://thebell.io/lavrov-rossiya-i-turtsiya-budut-dogovarivatsya-po-idlibu/',
#   '28 февраля 2020'),
#  ('https://thebell.io/katerina-tihonova-vozglavit-institut-pri-mgu/',
#   '28 февраля 2020'),
#  ('https://thebell.io/velikobritaniya-kupila-u-rossii-mnogo-zolota-pered-brexit/',
#   '28 февраля 2020'),
# ...

# %%
months
# Out:
# {'января': '01',
#  'февраля': '02',
#  'марта': '03',
#  'апреля': '04',
#  'мая': '05',
#  'июня': '06',
#  'июля': '07',
#  'августа': '08',
#  'сентября': '09',
#  'октября': '10',
#  'ноября': '11',
#  'декабря': '12'}

# %%
thebell_links = defaultdict(list)
for page in tqdm_notebook(range(99, 410)):
    link = f'https://thebell.io/category/news/page/{page}/'
    r = requests.get(link)
    soup = BS(r.text)
    
    for div in soup.find_all('div', 'news-item-row'):
        if div.find('span'):
            date = div.find('span', 'news-item__info').text.split()
            date = f'{date[2]}.{months[date[1]]}.{date[0]}'
            thebell_links[date].append(div.find('a', 'news-item__link')['href'])

with open('thebell_links.json', 'w', encoding = 'utf-8') as f:
    json.dump(thebell_links, f)

#     [(div.find('a', 'news-item__link')['href'], div.find('span', 'news-item__info').text) for div in 
#      soup.find_all('div', 'news-item-row') if div.find('span')]

# %%
thebell_links
# Out:
# defaultdict(list,
#             {'2020.02.29': ['https://thebell.io/rospotrebnadzor-rekomendoval-vozderzhatsya-ot-poezdok-za-granitsu-iz-za-koronavirusa/'],
#              '2020.02.28': ['https://thebell.io/tsena-nefti-probila-otmetku-v-49-za-barrel/',
#               'https://thebell.io/rynki-v-ssha-otkrylis-novym-obvalom-rossijskie-indeksy-teryayut-5-6/',
#               'https://thebell.io/yandeks-stal-skryvat-publikatsii-o-rodstvennike-premera-mishustina/',
#               'https://thebell.io/zhenevskij-avtosalon-otmenen-iz-za-koronavirusa/',
#               'https://thebell.io/koronavirus-ster-5-trln-mirovoj-kapitalizatsii/',
#               'https://thebell.io/lavrov-rossiya-i-turtsiya-budut-dogovarivatsya-po-idlibu/',
#               'https://thebell.io/katerina-tihonova-vozglavit-institut-pri-mgu/',
#               'https://thebell.io/velikobritaniya-kupila-u-rossii-mnogo-zolota-pered-brexit/',
# ...

# %%
thebell_19_20 = []
for date in tqdm_notebook(sorted(list(thebell_links.keys()))):
    for link in tqdm_notebook(thebell_links[date]):
        try:
            r = requests.get(link)
            soup = BS(r.text)
            if len(date)==9:
                date = date[:-1]+'0'+date[-1]
            thebell_19_20.append({'Media':'thebell.io', 'Date':date, 'Link':link,
                                  'Text':'. '.join([soup.h1.text, ' '.join([p.text for p in soup.article.find_all('p') 
                                                                            if p.text and 'Фото:' not in p.text][:-1])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(thebell_19_20).to_csv('thebell_19_20.csv', encoding='utf-8')
pd.DataFrame(thebell_19_20).to_csv('thebell_19_20.csv', encoding='utf-8')
pd.DataFrame(thebell_19_20)
# Out:
# ...
#            Media        Date  \
# 0     thebell.io  2019.01.01
# 1     thebell.io  2019.01.01
# 2     thebell.io  2019.01.01
# 3     thebell.io  2019.01.10
# 4     thebell.io  2019.01.10
# ...          ...         ...
# 3105  thebell.io  2020.02.08
# 3106  thebell.io  2020.02.08
# 3107  thebell.io  2020.02.09
# 3108  thebell.io  2020.02.09
# 3109  thebell.io  2020.02.09
#
#                                                    Link  \
# 0     https://thebell.io/sergej-sobyanin-uvolil-gend...
# 1     https://thebell.io/2018-god-okazalsya-dlya-fon...
# 2     https://thebell.io/tragediya-v-magnitogorske-c...
# 3     https://thebell.io/tsentr-dose-rasskazal-o-svy...
# 4     https://thebell.io/roskomnadzor-obvinil-bi-bi-...
# ...                                                 ...
# 3105  https://thebell.io/kitajskie-aviakompanii-nach...
# 3106  https://thebell.io/vlasti-ssha-ispolzuyut-geol...
# 3107  https://thebell.io/oskar-2020-glavnye-pretende...
# ...

# %%
thebell_links['2020.01.16']
# Out:
# ['https://thebell.io/startap-elektrogruzovikov-osnovatelya-yota-otsenen-v-3-mlrd/',
#  'https://thebell.io/putin-obyasnil-smysl-konstitutsionnoj-reformy/',
#  'https://thebell.io/obvinyaemuyu-v-shpionazhe-byvshego-top-menedzhera-inter-rao/',
#  'https://thebell.io/mishustin-rasskazal-o-planah-na-postu-premera/',
#  'https://thebell.io/mosbirzha-i-analitiki-zhdut-buma-ipo-v-2020-godu/']

# %%
def get_article_thebell(link):
    r = requests.get(link)
    soup = BS(r.text)
    return '. '.join([soup.h1.text, ' '.join([p.text for p in soup.article.find_all('p') if p.text and 'Фото:' not in p.text][:-1])])
