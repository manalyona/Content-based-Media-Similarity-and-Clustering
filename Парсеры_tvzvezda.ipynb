# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as BS
import re
from math import ceil
from tqdm import tqdm_notebook
from collections import Counter, defaultdict
from operator import itemgetter

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import json

# %% [markdown]
# ## Zvezda

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
zvezda_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        zvezda_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.tvzvezda.ru%20OR%20domainis:tvzvezda.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                zvezda_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('zvezda_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(zvezda_20, f)
# Out:
# ...
# 2020.01.01 50
# 2020.01.01 37
# 2020.01.02 41
# 2020.01.02 48
# 2020.01.03 50
# 2020.01.03 40
# 2020.01.04 54
# 2020.01.04 45
# 2020.01.05 37
# 2020.01.05 42
# 2020.01.06 44
# 2020.01.06 30
# 2020.01.07 44
# 2020.01.07 37
# 2020.01.08 48
# 2020.01.08 49
# 2020.01.09 49
# 2020.01.09 42
# 2020.01.10 39
# 2020.01.10 35
# 2020.01.11 40
# 2020.01.11 43
# 2020.01.12 39
# 2020.01.12 42
# 2020.01.13 29
# 2020.01.13 66
# 2020.01.14 57
# 2020.01.14 47
# 2020.01.15 50
# 2020.01.15 54
# 2020.01.16 39
# 2020.01.16 62
# 2020.01.17 60
# 2020.01.17 45
# 2020.01.18 33
# 2020.01.18 45
# 2020.01.19 36
# 2020.01.19 49
# 2020.01.20 50
# 2020.01.20 56
# 2020.01.21 53
# 2020.01.21 50
# 2020.01.22 36
# 2020.01.22 56
# 2020.01.23 29
# 2020.01.23 36
# 2020.01.24 27
# 2020.01.24 33
# 2020.01.25 24
# 2020.01.25 44
# 2020.01.26 21
# 2020.01.26 39
# 2020.01.27 33
# 2020.01.27 61
# 2020.01.28 52
# 2020.01.28 66
# 2020.01.29 41
# 2020.01.29 63
# 2020.01.30 51
# 2020.01.30 60
# 2020.01.31 38
# 2020.01.31 63
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
tvzvezda_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        tvzvezda_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.tvzvezda.ru%20OR%20domainis:tvzvezda.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
#                 url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.mk.ru%20OR%20domainis:mk.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
    #             url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.kp.ru%20OR%20domainis:kp.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                tvzvezda_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('tvzvezda_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(tvzvezda_19, f)
# Out:
# ...
# 2019.01.01 24
# 2019.01.01 43
# 2019.01.02 30
# 2019.01.02 44
# 2019.01.03 43
# 2019.01.03 36
# 2019.01.04 44
# 2019.01.04 40
# 2019.01.05 30
# 2019.01.05 39
# 2019.01.06 19
# 2019.01.06 52
# 2019.01.07 59
# 2019.01.07 58
# 2019.01.08 30
# 2019.01.08 55
# 2019.01.09 60
# 2019.01.09 64
# 2019.01.10 65
# 2019.01.10 54
# 2019.01.11 45
# 2019.01.11 61
# 2019.01.12 56
# 2019.01.12 56
# 2019.01.13 36
# 2019.01.13 56
# 2019.01.14 48
# 2019.01.14 68
# 2019.01.15 69
# 2019.01.15 68
# 2019.01.16 63
# 2019.01.16 58
# 2019.01.17 63
# 2019.01.17 52
# 2019.01.18 62
# 2019.01.18 61
# 2019.01.19 51
# 2019.01.19 41
# 2019.01.20 41
# 2019.01.20 40
# 2019.01.21 35
# 2019.01.21 56
# 2019.01.22 54
# 2019.01.22 55
# 2019.01.23 55
# 2019.01.23 53
# 2019.01.24 55
# 2019.01.24 41
# 2019.01.25 52
# 2019.01.25 48
# 2019.01.26 57
# 2019.01.26 48
# 2019.01.27 43
# 2019.01.27 49
# 2019.01.28 65
# 2019.01.28 56
# 2019.01.29 54
# 2019.01.29 52
# 2019.01.30 65
# 2019.01.30 63
# 2019.01.31 67
# 2019.01.31 61
# ...

# %%
tvzvezda_19['2019.03.01']
# Out:
# ['https://tvzvezda.ru/news/forces/content/201903010831-tlvl.htm',
#  'https://tvzvezda.ru/news/opk/content/2019311015-8Lnf9.html',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/2019311057-toqY9.html',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903011017-4249.htm',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903011057-2k6d.htm',
#  'https://tvzvezda.ru/schedule/programs/content/201610171325-2nie.htm/201903010839-nhi8.htm',
#  'https://tvzvezda.ru/news/opk/content/2019311041-GdDAN.html',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903011037-khbm.htm',
#  'https://tvzvezda.ru/news/forces/content/201903010850-tym9.htm',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903011005-40tc.htm',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903010804-dcrm.htm',
#  'https://tvzvezda.ru/schedule/programs/content/201808231539-wgb0.htm/201903010847-93q0.htm',
#  'https://tvzvezda.ru/news/vstrane_i_mire/content/201903011109-t3r9.htm',
# ...

# %%
for link in tvzvezda_19['2019.03.01']:
# link = 'https://tvzvezda.ru/news/forces/content/201903010831-tlvl.htm'
    r = requests.get(link)
    soup = BeautifulSoup(r.text)

    ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'glav_text').find_all('p')])])

# %%
tvzvezda_2020 = []
for date in tqdm_notebook(list(zvezda_20.keys())):
    for link in tqdm_notebook(zvezda_20[date]):
#         if link not in pd.DataFrame(tvzvezda_2020).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            tvzvezda_2020.append({'Media':'tvzvezda.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'glav_text').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(tvzvezda_2020).to_csv('tvzvezda_2020.csv', encoding='utf-8')
pd.DataFrame(tvzvezda_2020).to_csv('tvzvezda_2020.csv', encoding='utf-8')
pd.DataFrame(tvzvezda_2020)
# Out:
# ...
#             Media        Date  \
# 0     tvzvezda.ru  2020.01.01
# 1     tvzvezda.ru  2020.01.01
# 2     tvzvezda.ru  2020.01.01
# 3     tvzvezda.ru  2020.01.01
# 4     tvzvezda.ru  2020.01.01
# ...           ...         ...
# 5501  tvzvezda.ru  2020.02.28
# 5502  tvzvezda.ru  2020.02.28
# 5503  tvzvezda.ru  2020.02.28
# 5504  tvzvezda.ru  2020.02.28
# 5505  tvzvezda.ru  2020.02.28
#
#                                                    Link  \
# 0     https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 1     https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 2     https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 3     https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 4     https://tvzvezda.ru/news/vstrane_i_mire/conten...
# ...                                                 ...
# 5501  https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 5502  https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 5503  https://tvzvezda.ru/news/vstrane_i_mire/conten...
# ...

# %%
with open('tvzvezda_2019.csv', encoding='utf-8') as f:
    tvzvezda_2019 = pd.read_csv(f)

# %%
list(tvzvezda_2019.values)
# Out:
# [array([0, 'tvzvezda.ru', '2019.01.01',
#         'https://tvzvezda.ru/news/vstrane_i_mire/content/201901011042-ab9a.htm',
# ...

# %%
with open('tvzvezda_links_2019.json', encoding='utf-8') as f:
    tvzvezda_19 = json.load(f)

# %%
tvzvezda_2019_add = []
for date in tqdm_notebook(list(tvzvezda_19.keys())[245:]):
    for link in tqdm_notebook(tvzvezda_19[date]):
#         if link not in pd.DataFrame(lenta_2019).Link:
        try:
            r = requests.get(link)
            soup = BeautifulSoup(r.text)
            tvzvezda_2019_add.append({'Media':'tvzvezda.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'glav_text').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(tvzvezda_2019_add).to_csv('tvzvezda_2019_add.csv', encoding='utf-8')
pd.DataFrame(tvzvezda_2019_add).to_csv('tvzvezda_2019_add.csv', encoding='utf-8')
pd.DataFrame(tvzvezda_2019_add)
# Out:
# ...
# https://tvzvezda.ru/news/vstrane_i_mire/content/201910151257-rS3fp.html
# ...
#              Media        Date  \
# 0      tvzvezda.ru  2019.09.03
# 1      tvzvezda.ru  2019.09.03
# 2      tvzvezda.ru  2019.09.03
# 3      tvzvezda.ru  2019.09.03
# 4      tvzvezda.ru  2019.09.03
# ...            ...         ...
# 13065  tvzvezda.ru  2019.12.31
# 13066  tvzvezda.ru  2019.12.31
# 13067  tvzvezda.ru  2019.12.31
# 13068  tvzvezda.ru  2019.12.31
# 13069  tvzvezda.ru  2019.12.31
#
#                                                     Link  \
# 0      https://tvzvezda.ru/schedule/programs/content/...
# 1      https://tvzvezda.ru/schedule/programs/content/...
# 2      https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 3      https://tvzvezda.ru/news/vstrane_i_mire/conten...
# 4      https://tvzvezda.ru/news/vstrane_i_mire/conten...
# ...                                                  ...
# 13065  https://tvzvezda.ru/news/vstrane_i_mire/conten...
# ...

# %% [markdown]
# ## Vesti.ru

# %%
vesti_20 = dict()
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '080000'], ['080000', '160000'],['160000', '235959']]
lenta_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        lenta_19[f'2019.{month:02d}.{day+1:02d}'] = []
        
for text in ['заявил', 'говорит', 'считает', 'известия', 
             'рассказал', 'написал', 'сообщил', 'сообщает', 
             'объяснил', 'попал', 'вышла', 'передает', 'пришли', 
             'появился', 'рублей', 'тысяч', 'штраф', 'километров']:
    link = f'https://motor.ru/search?query={text}'
    r = requests.get(link)
    soup = BeautifulSoup(r.text)
    while True:
        link = f'https://motor.ru/search?page={i}&query={text}'
        print('link', link)
        r = requests.get(link)
        soup = BeautifulSoup(r.text)
        links_temp = ['https://motor.ru'+div.a['href'] for div in soup.find_all('div', 'item')[8:] if div.a]
        print('links_temp\n', links_temp)
        [vesti_20.add(link_temp) for link_temp in links_temp]
        if:
            break
links

# %%
# link = 'https://www.vesti.ru/search/showmore/q/%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB/date_start/01.01.2020/date_end/03.01.2020/p/2'
link = 'https://www.vesti.ru/search/showmore/q/%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB/date_start/01.01.2020/date_end/01.01.2020/p/1'
link = 'https://www.vesti.ru/search/showmore/q/%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB/date_start/01.01.2020/date_end/03.01.2020/p/2'
link = 'https://www.vesti.ru/search/showmore/q/%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB/date_start/01.01.2020/date_end/03.01.2020/p/3'
r = requests.get(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'})
r.json()
# soup = BeautifulSoup(r.json()['html'])
# soup = BeautifulSoup(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-100-c24e846fa44a> in <module>
#       4 link = 'https://www.vesti.ru/search/showmore/q/%D1%81%D0%BE%D0%BE%D0%B1%D1%89%D0%B8%D0%BB/date_start/01.01.2020/date_end/03.01.2020/p/3'
#       5 r = requests.get(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'})
# ----> 6 r.json()
#       7 # soup = BeautifulSoup(r.json()['html'])
#       8 # soup = BeautifulSoup(r.text)
#
# ~\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
soup.find_all('div', 'search-item')
# Out:
# []

# %%
['https://www.vesti.ru'+div.find('a')['href'] for div in soup.find_all('div', 'search-item')]
# Out:
# ['https://www.vesti.ru/doc.html?id=3226622',
#  'https://www.vesti.ru/doc.html?id=3226552',
#  'https://www.vesti.ru/doc.html?id=3226640',
#  'https://www.vesti.ru/doc.html?id=3226620',
#  'https://www.vesti.ru/doc.html?id=3226611',
#  'https://www.vesti.ru/doc.html?id=3226540',
#  'https://www.vesti.ru/doc.html?id=3226566',
#  'https://www.vesti.ru/doc.html?id=3226534',
#  'https://www.vesti.ru/doc.html?id=3226533',
#  'https://www.vesti.ru/doc.html?id=3226532']

# %%
soup.find_all('div', 'search-item')
# Out:
# [<div class="search-item">
#  <div class="search-item__date">
#  <p class="search-item__date__time">10:07</p>
#  <p class="search-item__date__day">3 января 2020</p>
#  </div>
#  <div class="search-item__content">
#  <h3><a href="/doc.html?id=3226622"> В Белоруссии сообщили о прекращении поставок нефти из России </a></h3>
#  <p><a href="/doc.html?id=3226622">По информации белорусских НПЗ, у них нет контрактов с российскими НК, и работа ведется на остатках сырья.</a></p>
#  </div>
#  </div>, <div class="search-item">
#  <div class="search-item__date">
#  <p class="search-item__date__time">09:35</p>
#  <p class="search-item__date__day">3 января 2020</p>
#  </div>
#  <div class="search-item__content">
#  <h3><a href="/doc.html?id=3226552"> Их ждут в России: самые ожидаемые автопремьеры 2020 года </a></h3>
# ...

# %% [markdown]
# ## ТАСС

# %%
url = 'https://tass.ru/userApi/search'
r = requests.post(url, json={"type":[],"sections":[],"searchStr":"",
                             "sort":"date","range":'',"from":400000,"size":100})
r.json()
# for i in r.json():
#     if 'link' in i.keys():
#         print(i['mark'], '\n', i['title'], '\n', 'https://tass.ru'+i['link'], '\n')
# Out:
# [{'id': 5431193,
#   'sectionId': 24,
#   'type': 'default',
#   'isFlash': False,
#   'isOnline': False,
#   'date': 1533494617,
#   'update': True,
#   'title': 'Марадона выразил поддержку пережившему покушение президенту Венесуэлы',
#   'subtitle': '',
#   'lead': 'Бывший футболист также назвал Николаса Мадуро своим другом',
#   'image': None,
#   'link': '/obschestvo/5431193',
#   'mark': 'Покушение на президента Венесуэлы',
#   'sponsor_id': None,
#   'sponsor_type_id': None},
#  {'id': 5431160,
#   'sectionId': 25,
#   'type': 'default',
#   'isFlash': False,
#   'isOnline': False,
#   'date': 1533494401,
#   'update': True,
#   'title': 'Годовой эффект от учений ПАО "Россети" в Дагестане составит 150 млн рублей',
#   'subtitle': '',
#   'lead': 'Средства предполагается направить на развитие энергетической инфраструктуры региона',
#   'image': None,
#   'link': '/ekonomika/5431160',
#   'mark': 'Всероссийские учения энергетиков в Дагестане',
#   'sponsor_id': None,
# ...

# %%
tass_20 = pd.read_csv('tass_2020.csv')
tass_20
# Out:
#        Unnamed: 0    Media        Date  \
# 0               0  tass.ru  2020.01.01
# 1               1  tass.ru  2020.01.01
# 2               2  tass.ru  2020.01.01
# 3               3  tass.ru  2020.01.01
# 4               4  tass.ru  2020.01.01
# ...           ...      ...         ...
# 19430       19430  tass.ru  2020.02.28
# 19431       19431  tass.ru  2020.02.28
# 19432       19432  tass.ru  2020.02.28
# 19433       19433  tass.ru  2020.02.28
# 19434       19434  tass.ru  2020.02.28
#
#                                                    Link  \
# 0      https://tass.ru/mezhdunarodnaya-panorama/7456667
# 1                     https://tass.ru/ekonomika/7456617
# 2                       https://tass.ru/kultura/7456557
# 3      https://tass.ru/mezhdunarodnaya-panorama/7456571
# 4      https://tass.ru/mezhdunarodnaya-panorama/7456609
# ...                                                 ...
# 19430       https://tass.ru/nacionalnye-proekty/7865275
# ...

# %%
tass_20[tass_20.Date=='2020.02.02'].Link
# Out:
# 9787                  https://tass.ru/obschestvo/7664849
# 9788              https://tass.ru/proisshestviya/7664891
# 9789                    https://tass.ru/politika/7664833
# 9790              https://tass.ru/proisshestviya/7664869
# 9791                  https://tass.ru/obschestvo/7664879
#                               ...
# 9967                      https://tass.ru/kosmos/7667173
# 9968                  https://tass.ru/obschestvo/7667203
# 9969    https://tass.ru/mezhdunarodnaya-panorama/7667225
# 9970                    https://tass.ru/politika/7667085
# 9971                  https://tass.ru/obschestvo/7667215
# Name: Link, Length: 185, dtype: object

# %%
tass_20['Tags'] =[[]]*len(tass_20)

# %%
# tags = []
for link in tqdm_notebook(tass_20.Link[15219:]):
#     print(link)
    r = requests.get(link)
    soup = BS(r.text)
    tag = soup.find('div', 'news-header__marker')
    if tag:
        try:
            tass_20.loc[tass_20.Link==link, 'Tags'] = [tag.a.text]
            if tag.a.text not in tags:
                print(tag.a.text)
                tags.append(tag.a.text)
        except (AttributeError, IndexError):
            print(link)
# Out:
# ...
# https://tass.ru/obschestvo/7755983
# Борьба с изменениями климата
# Дело Хорошавина
# Освоение Арктики
# Скандал вокруг топ-менеджера Росгеологии
# Диалог России и Украины
# Сельское хозяйство
# Интервью Владимира Путина ТАСС
# Проект бюджета на 2020-2022 годы
# Пенсионный закон
# Жесткая посадка Ан-2 в Магадане
# Стрельба в Ханау
# Миграционная ситуация в РФ
# Обязательное медицинское страхование
# Крушение Л-39 Минобороны РФ в Азовском море
# Курорты Северного Кавказа
# Массовый спорт
# Обыски у сборной России по биатлону на ЧМ в Италии
# Чемпионат мира по биатлону
# Дело основателя Vee Security Александра Литреева
# Марсианский зонд InSight
# Евро-2020
# "Болотное дело"
# Ливия: исламисты против армии
# Дело экс-мэра Ярославля Евгения Урлашова
# Ситуация с ценами на бензин в России
# Расследование гибели моряков на глубоководном аппарате ВМФ
# Вопрос участия россиян в международных соревнованиях
# Вывод войск США из Сирии
# Отказ в визах российской делегации на Генассамблее ООН
# ...

# %%
tass_20.drop(columns=['Unnamed: 0', 'Dep'])
# Out:
#          Media        Date                                              Link  \
# 0      tass.ru  2020.01.01  https://tass.ru/mezhdunarodnaya-panorama/7456667
# 1      tass.ru  2020.01.01                 https://tass.ru/ekonomika/7456617
# 2      tass.ru  2020.01.01                   https://tass.ru/kultura/7456557
# 3      tass.ru  2020.01.01  https://tass.ru/mezhdunarodnaya-panorama/7456571
# 4      tass.ru  2020.01.01  https://tass.ru/mezhdunarodnaya-panorama/7456609
# ...        ...         ...                                               ...
# 19430  tass.ru  2020.02.28       https://tass.ru/nacionalnye-proekty/7865275
# 19431  tass.ru  2020.02.28                https://tass.ru/obschestvo/7865099
# 19432  tass.ru  2020.02.28                https://tass.ru/obschestvo/7865213
# 19433  tass.ru  2020.02.28  https://tass.ru/mezhdunarodnaya-panorama/7865371
# 19434  tass.ru  2020.02.28  https://tass.ru/mezhdunarodnaya-panorama/7865299
#
# ...

# %%
tass_20.to_csv('tass_2020_tags.csv', encoding = 'utf-8')

# %%
df.loc[df['b']==5, 'd'] = 1

# %%
df
# Out:
#    a  b  c  d
# 0  1  3  6  7
# 1  2  5  7  1
# 2  3  6  9  2

# %% [markdown]
# ## Championat

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
championat_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        championat_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.championat.com%20OR%20domainis:championat.com)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                championat_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('championat_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(championat_20, f)
# Out:
# ...
# 2020.01.01 12
# 2020.01.01 21
# 2020.01.02 19
# 2020.01.02 28
# 2020.01.03 28
# 2020.01.03 34
# 2020.01.04 15
# 2020.01.04 41
# 2020.01.05 15
# 2020.01.05 31
# 2020.01.06 15
# 2020.01.06 33
# 2020.01.07 16
# 2020.01.07 39
# 2020.01.08 18
# 2020.01.08 34
# 2020.01.09 15
# 2020.01.09 36
# 2020.01.10 18
# 2020.01.10 38
# 2020.01.11 16
# 2020.01.11 41
# 2020.01.12 20
# 2020.01.12 44
# 2020.01.13 22
# 2020.01.13 42
# 2020.01.14 39
# 2020.01.14 46
# 2020.01.15 25
# 2020.01.15 56
# 2020.01.16 23
# 2020.01.16 30
# 2020.01.17 32
# 2020.01.17 36
# 2020.01.18 28
# 2020.01.18 51
# 2020.01.19 37
# 2020.01.19 47
# 2020.01.20 21
# 2020.01.20 46
# 2020.01.21 24
# 2020.01.21 33
# 2020.01.22 24
# 2020.01.22 31
# 2020.01.23 34
# 2020.01.23 36
# 2020.01.24 34
# 2020.01.24 49
# 2020.01.25 28
# 2020.01.25 35
# 2020.01.26 37
# 2020.01.26 31
# 2020.01.27 14
# 2020.01.27 26
# 2020.01.28 22
# 2020.01.28 30
# 2020.01.29 21
# 2020.01.29 36
# 2020.01.30 31
# 2020.01.30 32
# 2020.01.31 27
# 2020.01.31 33
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
championat_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        championat_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.championat.com%20OR%20domainis:championat.com)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                championat_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
with open('championat_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(championat_19, f)
# Out:
# ...
# 2019.01.01 9
# 2019.01.01 22
# 2019.01.02 9
# 2019.01.02 16
# 2019.01.03 12
# 2019.01.03 16
# 2019.01.04 12
# 2019.01.04 22
# 2019.01.05 4
# 2019.01.05 21
# 2019.01.06 8
# 2019.01.06 27
# 2019.01.07 12
# 2019.01.07 27
# 2019.01.08 8
# 2019.01.08 15
# 2019.01.09 19
# 2019.01.09 26
# 2019.01.10 10
# 2019.01.10 16
# 2019.01.11 17
# 2019.01.11 38
# 2019.01.12 16
# 2019.01.12 34
# 2019.01.13 8
# 2019.01.13 33
# 2019.01.14 12
# 2019.01.14 34
# 2019.01.15 18
# 2019.01.15 20
# 2019.01.16 20
# 2019.01.16 30
# 2019.01.17 23
# 2019.01.17 20
# 2019.01.18 17
# 2019.01.18 24
# 2019.01.19 18
# 2019.01.19 18
# 2019.01.20 14
# 2019.01.20 26
# 2019.01.21 21
# 2019.01.21 16
# 2019.01.22 16
# 2019.01.22 19
# 2019.01.23 24
# 2019.01.23 20
# 2019.01.24 18
# 2019.01.24 24
# 2019.01.25 19
# 2019.01.25 22
# 2019.01.26 26
# 2019.01.26 37
# 2019.01.27 27
# 2019.01.27 33
# 2019.01.28 15
# 2019.01.28 24
# 2019.01.29 8
# 2019.01.29 27
# 2019.01.30 14
# 2019.01.30 20
# 2019.01.31 9
# 2019.01.31 18
# ...
# 2019.02.01 19
# ...

# %%
[print(link) for link in championat_20['2020.01.18']]
# Out:
# https://www.championat.com/tennis/news-3950207-rubljov-oderzhal-razgromnuju-pobedu-v-finale-turnira-v-adelaide-i-zavoeval-vtoroj-titul-krjadu.html
# https://www.championat.com/hockey/article-3950143-detrojt---pittsburg---12-ot-obzor-matcha-video-gola-krosbi-s-peredachi-malkina.html
# https://www.championat.com/bets/article-3949681-konor-makgregor---donald-serrone-19-janvarja-2020-kotirovki-i-stavki-na-boj-ufc-246.html
# https://www.championat.com/boxing/news-3950205-dillon-denis-mne-strashno-za-serrone.html
# https://www.championat.com/biathlon/news-3950191-vita-semerenko-sostav-u-nas-boevoj-pensionerskij-my-dolzhny-byt-na-pedestale.html
# https://www.championat.com/biathlon/article-3950105-kak-zhenskaja-sbornaja-rossii-po-biatlonu-vyberetsja-iz-zatjazhnogo-krizisa.html
# https://www.championat.com/bets/news-3949987-njukasl-junajted---chelsi-prognoz-chempionata-bonus-do-10-000-rublej-na-stavku.html
# ...

# %%
for link in championat_20['2020.01.18']:
# link = 'https://www.championat.com/tennis/news-3950207-rubljov-oderzhal-razgromnuju-pobedu-v-finale-turnira-v-adelaide-i-zavoeval-vtoroj-titul-krjadu.html'
    try:
        r = requests.get(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'})
        soup = BS(r.text)

        ' '.join([soup.find('div', 'article-head__title').text, ' '.join([p.text for p in soup.find('div', 'article-content').find_all('p')])])
    except (AttributeError, IndexError):
        print(link)

# %%
championat_2020 = []
for date in tqdm_notebook(list(championat_20.keys())):
    for link in tqdm_notebook(championat_20[date]):
#         if link not in pd.DataFrame(tvzvezda_2020).Link:
        try:
            r = requests.get(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'})
            soup = BeautifulSoup(r.text)
            championat_2020.append({'Media':'championat.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.find('div', 'article-head__title').text, 
                                                   ' '.join([p.text for p in 
                                                             soup.find('div', 'article-content').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(championat_2020).to_csv('championat_2020.csv', encoding='utf-8')
pd.DataFrame(championat_2020).to_csv('championat_2020.csv', encoding='utf-8')
pd.DataFrame(championat_2020)
# Out:
# ...
# https://www.championat.com/lifestyle/article-3880055-buduschie-chempiony-khl-deti-rasskazyvajut-o-ljubimyh-igrokah-v-hokkee.html
# ...
# https://www.championat.com/other/news-3954853-gorjachkina---czjuj-venczjun-smotret-onlajn-taj-brejk-chm-po-shahmatam-24-janvarja-2020.html
# https://www.championat.com/other/news-3954849-gorjachkina---czjuj-venczjun-prjamaja-transljacija-24012020-chempionat-mira-po-shahmatam-2020.html
# ...
# https://www.championat.com/other/news-3957899-moskovskoe-dinamo-obygralo-zareche-odincovo-v-volejbolnoj-superlige.html
# ...
# https://www.championat.com/auto/news-3966738-v-bmv-ne-zainteresovany-v-vozvraschenii-v-formulu-1-v-2021-godu.html
# ...
#               Media        Date  \
# 0     championat.ru  2020.01.01
# 1     championat.ru  2020.01.01
# 2     championat.ru  2020.01.01
# 3     championat.ru  2020.01.01
# 4     championat.ru  2020.01.01
# ...             ...         ...
# 3758  championat.ru  2020.02.28
# 3759  championat.ru  2020.02.28
# 3760  championat.ru  2020.02.28
# ...

# %%
championat_2019 = []
for date in tqdm_notebook(list(championat_19.keys())):
    for link in tqdm_notebook(championat_19[date]):
#         if link not in pd.DataFrame(tvzvezda_2020).Link:
        try:
            r = requests.get(link, headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:75.0) Gecko/20100101 Firefox/75.0'})
            soup = BeautifulSoup(r.text)
            championat_2019.append({'Media':'championat.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.find('div', 'article-head__title').text, 
                                                   ' '.join([p.text for p in 
                                                             soup.find('div', 'article-content').find_all('p')])]), 
                                  'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(championat_2019).to_csv('championat_2019.csv', encoding='utf-8')
pd.DataFrame(championat_2019).to_csv('championat_2019.csv', encoding='utf-8')
pd.DataFrame(championat_2019)
# Out:
# ...
# https://www.championat.com/boxing/news-3642933-usik-mozhet-provesti-boj-s-povetkinym-ili-ortisom.html
# ...
# https://www.championat.com/boxing/news-3659189-promouter-usika-sledujuschij-boj-aleksandra-sostoitsja-18-ili-25-maja.html
# ...
# https://www.championat.com/auto/_f1/tournament/523/match/30199/
# ...
# https://www.championat.com/lifestyle/article-3687019-biohaking-v-rossii-intervju-s-juliej-enhel-kak-prozhit-dolshe.html
# ...
# https://www.championat.com/auto/news-3692801-kubica-gotov-k-etapu-v-avstralii-tolko-na-20-procentov.html
# ...
# https://www.championat.com/bets/article-3696163-ural--spartak-7-marta-2019-prognoz-na-match-kubka-rossii.html
# ...
# https://www.championat.com/boxing/news-3700149-istochnik-gran-kanarija-uvolit-garsija-i-postavit-glavnym-trenerom-martinesa.html
# ...
# https://www.championat.com/auto/news-3702365-stroll-teper-ja-snova-zhivu-nadezhdoj.html
# ...
# https://www.championat.com/bets/article-3705397-milan---inter-17-marta-2019-prognoz-na-match-serii-a.html
# ...

# %% [markdown]
# ## За рулем

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
zarulem_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        zarulem_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.zr.ru%20OR%20domainis:zr.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                zarulem_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
                
with open('zarulem_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(zarulem_20, f)
# Out:
# ...
# 2020.01.01 5
# 20200101
# 2020.01.02 5
# 20200102
# 2020.01.03 4
# 2020.01.03 1
# 2020.01.04 4
# 20200104
# 2020.01.05 3
# 20200105
# 2020.01.06 4
# 20200106
# 2020.01.07 4
# 20200107
# 2020.01.08 4
# 20200108
# 2020.01.09 10
# 2020.01.09 6
# 2020.01.10 9
# 2020.01.10 6
# 2020.01.11 4
# 20200111
# 2020.01.12 5
# 2020.01.12 1
# 2020.01.13 10
# 2020.01.13 9
# 2020.01.14 8
# 2020.01.14 9
# 2020.01.15 12
# 2020.01.15 15
# 2020.01.16 10
# 2020.01.16 8
# 2020.01.17 6
# 2020.01.17 13
# 2020.01.18 3
# 20200118
# 2020.01.19 4
# 20200119
# 2020.01.20 8
# 2020.01.20 13
# 2020.01.21 11
# 2020.01.21 8
# 2020.01.22 6
# 2020.01.22 9
# 2020.01.23 8
# 2020.01.23 6
# 2020.01.24 10
# 2020.01.24 3
# 2020.01.25 4
# 20200125
# 2020.01.26 3
# 2020.01.26 1
# 2020.01.27 7
# 2020.01.27 9
# 2020.01.28 9
# 2020.01.28 6
# 2020.01.29 10
# 2020.01.29 7
# 2020.01.30 9
# 2020.01.30 7
# 2020.01.31 5
# 2020.01.31 6
# ...
# 2020.02.01 5
# 2020.02.01 1
# 2020.02.02 4
# 2020.02.02 1
# 2020.02.03 6
# 2020.02.03 10
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
zarulem_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        zarulem_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.zr.ru%20OR%20domainis:zr.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                zarulem_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
                
with open('zarulem_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(zarulem_19, f)
# Out:
# ...
# 2019.01.01 2
# 2019.01.01 3
# 2019.01.02 2
# 20190102
# 2019.01.03 3
# 2019.01.03 1
# 2019.01.04 4
# 2019.01.04 1
# 2019.01.05 4
# 20190105
# 2019.01.06 4
# 20190106
# 2019.01.07 3
# 20190107
# 2019.01.08 5
# 2019.01.08 1
# 2019.01.09 10
# 2019.01.09 9
# 2019.01.10 10
# 2019.01.10 7
# 2019.01.11 10
# 2019.01.11 6
# 2019.01.12 5
# 2019.01.12 1
# 2019.01.13 2
# 2019.01.13 1
# 2019.01.14 6
# 2019.01.14 13
# 2019.01.15 11
# 2019.01.15 7
# 2019.01.16 10
# 2019.01.16 9
# 2019.01.17 11
# 2019.01.17 4
# 2019.01.18 10
# 2019.01.18 8
# 2019.01.19 4
# 2019.01.19 1
# 2019.01.20 4
# 2019.01.20 2
# 2019.01.21 8
# 2019.01.21 14
# 2019.01.22 7
# 2019.01.22 10
# 2019.01.23 4
# 2019.01.23 12
# 2019.01.24 12
# 2019.01.24 7
# 2019.01.25 7
# 2019.01.25 10
# 2019.01.26 3
# 2019.01.26 2
# 2019.01.27 4
# 2019.01.27 2
# 2019.01.28 14
# 2019.01.28 12
# 2019.01.29 16
# 2019.01.29 8
# 2019.01.30 12
# 2019.01.30 8
# 2019.01.31 11
# 2019.01.31 6
# ...
# 2019.02.01 11
# 2019.02.01 10
# 2019.02.02 4
# 20190202
# ...

# %%
zarulem_20['2020.01.16']
# Out:
# ['https://www.zr.ru/content/news/921283-novyj-hyundai-tucson-zakanchiva/',
#  'https://www.zr.ru/content/news/921280-khot-rody-dzhejmsa-khetfilda-iz-m/',
#  'https://www.zr.ru/content/news/921279-novyj-toyota-land-cruiser-na/',
#  'https://www.zr.ru/content/news/921282-sosed-kupil-dorogoj-avtomobil/',
#  'https://www.zr.ru/content/news/921267-nam-kazhetsya-chto-benzin-silno/',
#  'https://www.zr.ru/content/news/921281-chevrolet-niva-v-novom-godu-p/',
#  'https://www.zr.ru/content/news/921276-avtomobili-s-probegom-stali-do/',
#  'https://www.zr.ru/content/articles/921209-inspektor-prosit-projti-v-patrulniy-avtomobil/',
#  'https://www.zr.ru/content/articles/921242-chtoby-v-grante-stalo-tishe-so/',
#  'https://www.zr.ru/content/articles/921246-obnovlennyj-skoda-rapid-podro/',
#  'https://www.zr.ru/content/news/921286-krossover-genesis-gv80-novye/',
#  'https://www.zr.ru/content/articles/921254-novaya-razvodka-na-servise/',
# ...

# %%
link = 'https://www.zr.ru/content/news/921283-novyj-hyundai-tucson-zakanchiva/'
r = requests.get(link)
soup = BS(r.text)

' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'stroy_content').find_all('p') if p.text.strip() and 'Фото' not in p.text])]).replace('\xa0', ' ')
# Out:
# 'Новый Hyundai Tucson: заканчиваются испытания По мере готовности разрабатываемых и обновляемых моделей к производству они теряют камуфляж, но в Hyundai решили его, наоборот, добавить. Сейчас новое поколение Tucson проходит испытания в условиях низких температур. Обычно данные тесты становятся заключительными, после чего происходит показ новинки. Кроссовер отличается от предшественника решеткой радиатора более смелого дизайна, узкими фарами, сливающимися с ней, и покатой линией крыши, которая ниспадает от средних стоек к задним, а панели кузова выглядят более рельефными. Ожидается, что новый Hyundai Tucson для рынков разных стран будет оснащаться привычными для них двигателями. Например, Северная Америка, вероятно, получит 2,5-литровый мотор Theta3 в турбированных и безнаддувных версиях, агрегатирующийся с 8-ступенчатой автоматической коробкой передач. В Европе же, скорее всего, кроссовер предложат с 1,6-литровым четырехцилиндровым агрегатом GDI, турбированным 1,6-литровым T-GDI, диз
# ...

# %%
for link in zarulem_20['2020.01.16']:
    try:
        r = requests.get(link)
        soup = BS(r.text)

        ' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'stroy_content').find_all('p') if p.text.strip() and 'Фото' not in p.text])]).replace('\xa0', ' ')
    except (AttributeError, IndexError):
        print(link)

# %%
zarulem_2020 = []
for date in tqdm_notebook(list(zarulem_20.keys())):
    for link in tqdm_notebook(zarulem_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            zarulem_2020.append({'Media':'zr.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'stroy_content').find_all('p') if p.text.strip() and 'Фото' not in p.text])]).replace('\xa0', ' '),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(zarulem_2020).to_csv('zarulem_2020.csv', encoding='utf-8')
pd.DataFrame(zarulem_2020).to_csv('zarulem_2020.csv', encoding='utf-8')
pd.DataFrame(zarulem_2020)
# Out:
# ...
# https://www.zr.ru/safety/test-knowing-rules-road/
# ...
# https://www.zr.ru/cars/toyota/-/toyota-land-cruiser/reviews/
# https://www.zr.ru/content/articles/921290-servisnoe-obsluzhivanie-oficialnyj-diler/
# ...
# https://www.zr.ru/content/articles/921198-3-mifa-kia-soul/
# ...
# https://www.zr.ru/content/articles/921490-kia-soul-poezdka-test-drajv/
# ...
# https://www.zr.ru/cars/kia/-/seltos/reviews/
# https://www.zr.ru/cars/kia/-/seltos/stories/
# ...
# https://www.zr.ru/content/articles/921672-5-pravil-pri-zamene-masla/
# ...
# https://www.zr.ru/content/articles/921660-test-kia-soul-drive-wise/
# ...
# https://www.zr.ru/content/articles/921819-kia-soul-long-test/
# https://www.zr.ru/content/articles/921819-kia-soul-long-test/
#      Media        Date                                               Link  \
# 0    zr.ru  2020.01.01  https://www.zr.ru/content/articles/921135-yanv...
# 1    zr.ru  2020.01.01  https://www.zr.ru/content/articles/921055-konk...
# ...

# %%
zarulem_2019 = []
for date in tqdm_notebook(list(zarulem_19.keys())):
    for link in tqdm_notebook(zarulem_19[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            zarulem_2019.append({'Media':'zr.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text.strip() for p in soup.find('div', 'stroy_content').find_all('p') if p.text.strip() and 'Фото' not in p.text])]).replace('\xa0', ' '),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(zarulem_2019).to_csv('zarulem_2019.csv', encoding='utf-8')
pd.DataFrame(zarulem_2019).to_csv('zarulem_2019.csv', encoding='utf-8')
pd.DataFrame(zarulem_2019)
# Out:
# ...
# https://www.zr.ru/cars/nissan/-/nissan-almera/reviews/
# ...
# https://www.zr.ru/park-zr/kia-ceed/
# ...
# https://www.zr.ru/cars/mitsubishi/-/mitsubishi-l200/stories/
# ...
# https://www.zr.ru/content/news/916009-volvo-privezet-v-rossiyu-deshevy/
# ...
# https://www.zr.ru/content/articles/915444-viktorina-rosgosstrakh/
# ...
# https://www.zr.ru/content/articles/200001860-robotizirovannaya-avtomojka-izn/
# ...
# https://www.zr.ru/cars/nissan/-/nissan-murano/stories/
# https://www.zr.ru/cars/nissan/-/nissan-murano/
# https://www.zr.ru/cars/nissan/-/nissan-murano/news/
# ...
# https://www.zr.ru/cars/suzuki/-/suzuki-grand-vitara/stories/
# https://www.zr.ru/cars/suzuki/-/suzuki-grand-vitara/
# https://www.zr.ru/cars/suzuki/-/suzuki-grand-vitara/reviews/
# ...
# https://www.zr.ru/cars/subaru/-/subaru-impreza/
# ...
# https://www.zr.ru/cars/renault/-/renault-kangoo/stories/
# https://www.zr.ru/cars/renault/-/renault-master/stories/
# https://www.zr.ru/cars/renault/-/renault-master/
# https://www.zr.ru/cars/renault/-/renault-kangoo/
# ...

# %% [markdown]
# ## Авторевью

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
review_20 = dict()
for month in tqdm_notebook(list(months.keys())[:2]):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2020{month:02d}{day+1:02d}'
        review_20[f'2020.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.autoreview.ru%20OR%20domainis:autoreview.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                review_20[f'2020.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2020.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
                
with open('review_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(review_20, f)
# Out:
# ...
# 20200101
# 2020.01.01 1
# 20200102
# 20200102
# 20200103
# 2020.01.03 2
# 20200104
# 2020.01.04 1
# 20200105
# 20200105
# 2020.01.06 1
# 2020.01.06 1
# 20200107
# 20200107
# 2020.01.08 1
# 20200108
# 2020.01.09 1
# 2020.01.09 4
# 2020.01.10 1
# 2020.01.10 6
# 2020.01.11 1
# 20200111
# 20200112
# 2020.01.12 1
# 20200113
# 2020.01.13 8
# 20200114
# 2020.01.14 7
# 2020.01.15 3
# 2020.01.15 9
# 20200116
# 2020.01.16 4
# 2020.01.17 2
# 2020.01.17 3
# 2020.01.18 2
# 20200118
# 20200119
# 2020.01.19 4
# 2020.01.20 2
# 2020.01.20 5
# 2020.01.21 2
# 2020.01.21 5
# 20200122
# 2020.01.22 5
# 20200123
# 2020.01.23 4
# 20200124
# 2020.01.24 3
# 20200125
# 2020.01.25 1
# 20200126
# 2020.01.26 2
# 20200127
# 2020.01.27 6
# 20200128
# 2020.01.28 6
# 2020.01.29 3
# 2020.01.29 4
# 2020.01.30 2
# 2020.01.30 4
# 2020.01.31 3
# 2020.01.31 5
# ...
# 2020.02.01 2
# 2020.02.01 1
# 20200202
# 2020.02.02 1
# 20200203
# 2020.02.03 6
# 2020.02.04 2
# 2020.02.04 6
# 2020.02.05 4
# 2020.02.05 6
# 2020.02.06 4
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
times = [['000000', '120000'], ['120000', '235959']]
review_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'2019{month:02d}{day+1:02d}'
        review_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for time in times:
            try:
                url = f'https://api.gdeltproject.org/api/v2/doc/doc?query=%20(domain:.autoreview.ru%20OR%20domainis:autoreview.ru)%20sourcelang:rus&mode=ArtList&maxrecords=250&sort=DateDesc&format=html&startdatetime={date}{time[0]}&enddatetime={date}{time[1]}'
                r = requests.get(url)
                soup = BeautifulSoup(r.text)
                review_19[f'2019.{month:02d}.{day+1:02d}'].extend([a['href'] for a in soup.body.table.find_all('a')])
                print(f'2019.{month:02d}.{day+1:02d}', len(soup.body.table.find_all('a')))
            except (AttributeError, IndexError):
                print(date)
                
with open('review_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(review_19, f)
# Out:
# ...
# 20190101
# 2019.01.01 1
# 20190102
# 20190102
# 2019.01.03 1
# 2019.01.03 1
# 2019.01.04 1
# 2019.01.04 2
# 20190105
# 2019.01.05 1
# 20190106
# 2019.01.06 1
# 2019.01.07 1
# 2019.01.07 3
# 2019.01.08 1
# 2019.01.08 1
# 2019.01.09 2
# 2019.01.09 7
# 2019.01.10 1
# 2019.01.10 5
# 20190111
# 2019.01.11 7
# 20190112
# 20190112
# 20190113
# 2019.01.13 1
# 20190114
# 2019.01.14 8
# 2019.01.15 1
# 2019.01.15 10
# 2019.01.16 3
# 2019.01.16 9
# 2019.01.17 2
# 2019.01.17 7
# 2019.01.18 3
# 2019.01.18 6
# 2019.01.19 1
# 2019.01.19 2
# 20190120
# 2019.01.20 1
# 2019.01.21 1
# 2019.01.21 3
# 2019.01.22 2
# 2019.01.22 5
# 2019.01.23 2
# 2019.01.23 6
# 2019.01.24 7
# 2019.01.24 4
# 2019.01.25 1
# 2019.01.25 6
# 20190126
# 2019.01.26 1
# 20190127
# 2019.01.27 2
# 2019.01.28 2
# 2019.01.28 7
# 2019.01.29 2
# 2019.01.29 2
# 2019.01.30 2
# 2019.01.30 6
# 20190131
# 2019.01.31 4
# ...
# 2019.02.01 1
# 2019.02.01 4
# 20190202
# 2019.02.02 1
# 20190203
# 2019.02.03 1
# 2019.02.04 2
# 2019.02.04 7
# ...

# %%
review_20['2020.02.03']
# Out:
# ['https://autoreview.ru/news/krossover-volkswagen-taigun-staroe-imya-novyy-rynok',
#  'https://autoreview.ru/news/digest-200203',
#  'https://autoreview.ru/articles/gruzoviki-i-avtobusy/bankrot-kraz-vyzhivet-ili-net',
#  'https://autoreview.ru/articles/vtorye-ruki/optima-III',
#  'https://autoreview.ru/news/kia-seltos-v-rossii-ob-yavleny-komplektacii-i-ceny',
#  'https://autoreview.ru/news/daimler-predstavit-32-novye-modeli-za-tri-goda']

# %%
link = 'https://autoreview.ru/news/gibridnye-jeep-renegade-i-compass-vyhodyat-na-rynok'
r = requests.get(link)
soup = BS(r.text)

# %%
' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'full-article').find_all('p')])]).replace('\xa0', ' ')
# Out:
# 'Гибридные Jeep Renegade и Compass выходят на рынок Спустя почти год после дебюта первые гибридные Джипы выходят на европейский рынок. Кроссоверы Renegade и Compass с новой фирменной приставкой «4xe» уже можно заказать в Италии и Испании, скоро подтянутся и дилеры в других странах Евросоюза. Правда, пока можно оформить заявку только на самые дорогие версии First Edition, а варианты попроще появятся к лету.  Модели Renegade и Compass имеют унифицированные платформы, а потому и гибридная установка у них одна на двоих. Инженеры концерна FCA не стали городить сложную систему со встроенным в коробку передач электромотором, а пошли по пути концерна PSA: физически двигатель внутреннего сгорания и электромотор никак не связаны. Передние колеса приводит стандартная бензиновая турбочетверка 1.3 семейства GSE в паре с шестиступенчатым «автоматом», а задние колеса вращает отдельный электродвигатель.  На версиях First Edition бензиновый двигатель выдает 180 л.с. и 270 Нм, показатели электромотора
# ...

# %%
for link in review_20['2020.02.03']:
    try:
        r = requests.get(link)
        soup = BS(r.text)

        ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'full-article').find_all('p')])]).replace('\xa0', ' ')
    except (AttributeError, IndexError):
        print(link)

# %%
review_2020 = []
for date in tqdm_notebook(list(review_20.keys())):
    for link in tqdm_notebook(review_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            review_2020.append({'Media':'autoreview.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'full-article').find_all('p')])]).replace('\xa0', ' '),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(review_2020).to_csv('review_2020.csv', encoding='utf-8')
pd.DataFrame(review_2020).to_csv('review_2020.csv', encoding='utf-8')
pd.DataFrame(review_2020)
# Out:
# ...
# https://autoreview.ru/special/thirty-years/167362
# ...
# https://autoreview.ru/special/thirty-years/167354
# https://autoreview.ru/special/thirty-years/167367
# https://autoreview.ru/special/thirty-years/167361
# https://autoreview.ru/special/thirty-years/167371
# ...
# https://autoreview.ru/special/thirty-years/167369
# https://autoreview.ru/special/thirty-years/167375
# ...
# https://autoreview.ru/special/thirty-years/167353
# ...
# https://autoreview.ru/articles/svoimi-glazami/krasota-po-amerikanski
# ...
#              Media        Date  \
# 0    autoreview.ru  2020.01.01
# 1    autoreview.ru  2020.01.03
# 2    autoreview.ru  2020.01.03
# 3    autoreview.ru  2020.01.04
# 4    autoreview.ru  2020.01.06
# ..             ...         ...
# 267  autoreview.ru  2020.02.28
# 268  autoreview.ru  2020.02.28
# 269  autoreview.ru  2020.02.28
# 270  autoreview.ru  2020.02.28
# 271  autoreview.ru  2020.02.28
#
#                                                   Link  \
# ...

# %%
review_2019 = []
for date in tqdm_notebook(list(review_19.keys())):
    for link in tqdm_notebook(review_19[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            review_2019.append({'Media':'autoreview.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'full-article').find_all('p')])]).replace('\xa0', ' '),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(review_2019).to_csv('review_2019.csv', encoding='utf-8')
pd.DataFrame(review_2019).to_csv('review_2019.csv', encoding='utf-8')
pd.DataFrame(review_2019)
# Out:
# ...
# https://autoreview.ru/articles/gruzoviki-i-avtobusy/super-gazon-tramvai-i-elektrichki-my-pobyvali-na-fabrike-kompozitov
# ...
# https://autoreview.ru/articles/gruzoviki-i-avtobusy/cummins-huadong
# ...
# https://autoreview.ru/articles/pervaya-vstrecha/estafeta
# ...
# https://autoreview.ru/news/ukorochennyy-volkswagen-teramont-x-debyutiroval-v-seriynom-vide
# ...
# https://autoreview.ru/news/krossover-haval-f7-modifikacii-dlya-rossii
# ...
# https://autoreview.ru/articles/gruzoviki-i-avtobusy/renault-trucks-vypustit-ogranichennuyu-seriyu-tyagachey-k-yubileyu-no-k-kakomu-imenno
# ...
# https://autoreview.ru/news/opel-corsa-novogo-pokoleniya-rassekrecheny-vse-motory
# ...
# https://autoreview.ru/articles/blogi/clubmeeting-4
# ...
# https://autoreview.ru/club/blog/post/168702
# ...
# https://autoreview.ru/articles/blog-avtorevyu/vacancy-news
# ...
# https://autoreview.ru/articles/blog-avtorevyu/ischem-lexus-ls-dlya-sravnitel-nogo-testa
# ...
#               Media        Date  \
# 0     autoreview.ru  2019.01.01
# 1     autoreview.ru  2019.01.03
# ...

# %%
# dates = defaultdict(list)
page = 282
page = 488
for page in tqdm_notebook(range(282, 489)):
    link = f'https://www.sport-express.ru/search/page{page}/?sw=%F7%F2%EE&sportType=%C2%E8%E4+%F1%EF%EE%F0%F2%E0&kolonki=%CA%EE%EB%EE%ED%EA%E8&dt_to=&tp%5B0%5D=news'
    r = requests.get(link)
    soup = BS(r.text)
    for item in [(div.find('a', 'se19-search-item__title')['href'], 
                  div.find('p', 'se19-search-item__date').text.split(',')[0])
                 for div in soup.find('div', 'se19-search__results').find_all('div', 'se19-search-item')]:
        if 'января' in item[1]:
            dates[f'{item[1].split()[2]}.01.{item[1].split()[0]}'].append(item[0])
        if 'февраля' in item[1]:
            dates[f'{item[1].split()[2]}.02.{item[1].split()[0]}'].append(item[0])

# %%
dates.keys()
# Out:
# dict_keys(['2020.02.29', '2020.02.28', '2020.02.27', '2020.02.26', '2020.02.25', '2020.02.24', '2020.02.23', '2020.02.22', '2020.02.21', '2020.02.20', '2020.02.19', '2020.02.18', '2020.02.17', '2020.02.16', '2020.02.15', '2020.02.14', '2020.02.13', '2020.02.12', '2020.02.11', '2020.02.10', '2020.02.9', '2020.02.8', '2020.02.7', '2020.02.6', '2020.02.5', '2020.02.4', '2020.02.3', '2020.02.2', '2020.02.1', '2020.01.31', '2020.01.30', '2020.01.29', '2020.01.28', '2020.01.27', '2020.01.26', '2020.01.25', '2020.01.24', '2020.01.23', '2020.01.22', '2020.01.21', '2020.01.20', '2020.01.19', '2020.01.18', '2020.01.17', '2020.01.16', '2020.01.15', '2020.01.14', '2020.01.13', '2020.01.12', '2020.01.11', '2020.01.10', '2020.01.9', '2020.01.8', '2020.01.7', '2020.01.6', '2020.01.5', '2020.01.4', '2020.01.3', '2020.01.2', '2020.01.1'])

# %%
line = '2020.01.1'
line[:-1]+'0'+line[-1]
# Out:
# '2020.01.01'

# %%
for link in dates['2020.01.16']:

# link = 'https://www.sport-express.ru/hockey/nhl/news/istochnik-v-nhl-proyavlyayut-interes-k-bilyalovu-melnichuku-i-krasikovu-1632485/'
    r = requests.get(link)
    soup = BS(r.text)

    ' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'article_text').find_all('p')])]).replace('\xa0', ' ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-279-182d1d58779d> in <module>
#       2
#       3 # link = 'https://www.sport-express.ru/hockey/nhl/news/istochnik-v-nhl-proyavlyayut-interes-k-bilyalovu-melnichuku-i-krasikovu-1632485/'
# ----> 4     r = requests.get(link)
# ...

# %%
express_2020 = []
for date in tqdm_notebook(sorted(list(dates.keys()))):
    if len(date) == 9:
        date = date[:-1]+'0'+date[-1]
    for link in tqdm_notebook(dates[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            express_2020.append({'Media':'sport-express.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'article_text').find_all('p')])]).replace('\xa0', ' '),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(express_2020).to_csv('express_2020.csv', encoding='utf-8')
pd.DataFrame(express_2020).to_csv('express_2020.csv', encoding='utf-8')
pd.DataFrame(express_2020)
# Out:
# ...
#                  Media        Date  \
# 0     sport-express.ru  2020.01.10
# 1     sport-express.ru  2020.01.10
# 2     sport-express.ru  2020.01.10
# 3     sport-express.ru  2020.01.10
# 4     sport-express.ru  2020.01.10
# ...                ...         ...
# 4540  sport-express.ru  2020.02.29
# 4541  sport-express.ru  2020.02.29
# 4542  sport-express.ru  2020.02.29
# 4543  sport-express.ru  2020.02.29
# 4544  sport-express.ru  2020.02.29
#
#                                                    Link  \
# 0     https://www.sport-express.ru/tennis/atp/news/a...
# 1     https://www.sport-express.ru/hockey/khl/news/k...
# 2     https://www.sport-express.ru/football/england/...
# 3     https://www.sport-express.ru/cybersport/fifa/n...
# 4     https://www.sport-express.ru/football/spain/ne...
# ...                                                 ...
# 4540  https://www.sport-express.ru/basketball/eurole...
# 4541  https://www.sport-express.ru/athletics/news/v-...
# ...

# %% [markdown]
# ## Агентство Москва

# %%
link = 'https://www.mskagency.ru/?criteria=%D0%B8&from=09.04.2020&to=09.04.2020'
soup = BS(requests.get(link).text)

# %%
['https://www.mskagency.ru'+a['href'] for a in soup.find('ul', 'NewsList').find_all('a', 'js-title')]
# Out:
# ['https://www.mskagency.ru/materials/2992203',
#  'https://www.mskagency.ru/materials/2992315',
#  'https://www.mskagency.ru/materials/2992189',
#  'https://www.mskagency.ru/materials/2992171',
#  'https://www.mskagency.ru/materials/2992039']

# %%
date = '09.04.2020'
page = 1
while True:
    link = f'https://www.mskagency.ru/?criteria=%D0%B8&from={date}&to={date}&page={page}&last_date={date}&rnd=1&list_only=1'
    soup = BS(requests.get(link).text)
    # ['https://www.mskagency.ru'+a['href'] for a in soup.find('ul', 'NewsList').find_all('a', 'js-title')]
    links_temp = ['https://www.mskagency.ru'+a['href'] for a in soup.find_all('a', 'js-title')]
    if len(links_temp)<50:
        break
# Out:
# ['https://www.mskagency.ru/materials/2992011',
#  'https://www.mskagency.ru/materials/2992009',
#  'https://www.mskagency.ru/materials/2991789',
#  'https://www.mskagency.ru/materials/2992005',
#  'https://www.mskagency.ru/materials/2992001',
#  'https://www.mskagency.ru/materials/2991809',
#  'https://www.mskagency.ru/materials/2991997',
#  'https://www.mskagency.ru/materials/2991995',
#  'https://www.mskagency.ru/materials/2991849',
#  'https://www.mskagency.ru/materials/2991989',
#  'https://www.mskagency.ru/materials/2991985',
#  'https://www.mskagency.ru/materials/2991983',
#  'https://www.mskagency.ru/materials/2991957',
#  'https://www.mskagency.ru/materials/2991981',
#  'https://www.mskagency.ru/materials/2991973',
#  'https://www.mskagency.ru/materials/2991979',
#  'https://www.mskagency.ru/materials/2991599',
#  'https://www.mskagency.ru/materials/2991583',
#  'https://www.mskagency.ru/materials/2991709',
#  'https://www.mskagency.ru/materials/2991971',
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
# moscow_20 = dict()
for month in tqdm_notebook(list(months.keys())[1:2]):
    for day in tqdm_notebook(list(range(months[month]))[8:]):
        date = f'{day+1:02d}.{month:02d}.2020'
        moscow_20[f'2020.{month:02d}.{day+1:02d}'] = []
        page = 1
        while True:
            try:
                url = f'https://www.mskagency.ru/?criteria=%D0%B8&from={date}&to={date}&page={page}&last_date={date}&rnd=1&list_only=1'
                r = requests.get(url)
                soup = BS(r.text)
                links_temp = ['https://www.mskagency.ru'+a['href'] for a in soup.find_all('a', 'js-title')]
                moscow_20[f'2020.{month:02d}.{day+1:02d}'].extend(links_temp)
            except (AttributeError, IndexError):
                print(date)
                
            if len(links_temp) < 50:
                print(f'2020.{month:02d}.{day+1:02d}', len(moscow_20[f'2020.{month:02d}.{day+1:02d}']))
                break
            else:
                page += 1
                
with open('moscow_links_2020.json', 'w', encoding = 'utf-8') as f:
    json.dump(moscow_20, f)
# Out:
# ...
# 2020.02.09 38
# 2020.02.10 142
# 2020.02.11 145
# 2020.02.12 145
# 2020.02.13 155
# 2020.02.14 147
# 2020.02.15 48
# 2020.02.16 32
# 2020.02.17 133
# 2020.02.18 143
# 2020.02.19 144
# 2020.02.20 156
# 2020.02.21 157
# 2020.02.22 43
# 2020.02.23 35
# 2020.02.24 31
# 2020.02.25 116
# 2020.02.26 168
# 2020.02.27 136
# 2020.02.28 162

# %%
moscow_20['2020.02.08']
# Out:
# ['https://www.mskagency.ru/materials/2971715',
#  'https://www.mskagency.ru/materials/2971755',
#  'https://www.mskagency.ru/materials/2971749',
#  'https://www.mskagency.ru/materials/2971745',
#  'https://www.mskagency.ru/materials/2971743',
#  'https://www.mskagency.ru/materials/2971657',
#  'https://www.mskagency.ru/materials/2971741',
#  'https://www.mskagency.ru/materials/2971721',
#  'https://www.mskagency.ru/materials/2971725',
#  'https://www.mskagency.ru/materials/2971719',
#  'https://www.mskagency.ru/materials/2971713',
#  'https://www.mskagency.ru/materials/2971711',
#  'https://www.mskagency.ru/materials/2971653',
#  'https://www.mskagency.ru/materials/2971707',
#  'https://www.mskagency.ru/materials/2971703',
#  'https://www.mskagency.ru/materials/2971661',
#  'https://www.mskagency.ru/materials/2971705',
#  'https://www.mskagency.ru/materials/2971659',
#  'https://www.mskagency.ru/materials/2971701',
#  'https://www.mskagency.ru/materials/2971699',
# ...

# %%
url = 'https://www.mskagency.ru/materials/2971707'
r = requests.get(url)
soup = BS(r.text)

# %%
' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'text').find_all('p')])])
# Out:
# 'Премии правительства Москвы получили 87 молодых ученых Молодые ученые получили премии правительства столицы, сообщается на официальном сайте мэра Москвы. «7 февраля, в преддверии Дня науки, молодым ученым столицы вручили премии правительства Москвы. Сумма премий в этом году была увеличена - лауреаты получили 2 млн руб. вместо 500 тыс. Всего были отмечены проекты и разработки 87 ученых», - говорится в сообщении. Как поясняется, на получение премии могут претендовать аспиранты, кандидаты наук в возрасте до 36 лет и доктора наук до 40 лет включительно. Премии вручают по двум направлениям и 22 номинациям: за исследования в области математики, химии, физики, биологии, гуманитарных, общественных, технических и инженерных науках, ИКТ; за разработки в сфере биотехнологий, авиационной и космической техники, городской инфраструктуры, фармацевтики, нанотехнологий, приборостроения, электроники, энергосбережения, защиты информации. «В этом году мы вручили 50 премий 87 молодым ученым, работающим 
# ...

# %%
moscow_2020 = []
for date in tqdm_notebook(sorted(list(moscow_20.keys()))):
    for link in tqdm_notebook(moscow_20[date]):
#         if link not in pd.DataFrame(echo_2020).Link:
        try:
            r = requests.get(link)
            soup = BS(r.text)
            moscow_2020.append({'Media':'mskagency.ru', 'Date':date, 'Link':link,
                                  'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'text').find_all('p')])]),
                                 'Dep':'', 'Tags':[]})
        except (requests.exceptions.ConnectionError, AttributeError, 
                IndexError, requests.exceptions.TooManyRedirects, ValueError):
            print(link)
    if date.endswith('1'):
        pd.DataFrame(moscow_2020).to_csv('moscow_2020.csv', encoding='utf-8')
pd.DataFrame(moscow_2020).to_csv('moscow_2020.csv', encoding='utf-8')
pd.DataFrame(moscow_2020)
# Out:
# ...
# https://www.mskagency.ru/materials/2961789
# ...
# https://www.mskagency.ru/materials/2961867
# ...
# https://www.mskagency.ru/materials/2962715
# https://www.mskagency.ru/materials/2962495
# ...
# https://www.mskagency.ru/materials/2962881
# ...
# https://www.mskagency.ru/materials/2963125
# ...
# https://www.mskagency.ru/materials/2964679
# https://www.mskagency.ru/materials/2964517
# ...
# https://www.mskagency.ru/materials/2964757
# https://www.mskagency.ru/materials/2964701
# ...
# https://www.mskagency.ru/materials/2964899
# ...
# https://www.mskagency.ru/materials/2965025
# https://www.mskagency.ru/materials/2964995
# ...
# https://www.mskagency.ru/materials/2965421
# ...
# https://www.mskagency.ru/materials/2965995
# ...
# https://www.mskagency.ru/materials/2966639
# https://www.mskagency.ru/materials/2966487
# ...
# https://www.mskagency.ru/materials/2967225
# ...
# https://www.mskagency.ru/materials/2967565
# ...
# https://www.mskagency.ru/materials/2968303
# ...
# https://www.mskagency.ru/materials/2968847
# https://www.mskagency.ru/materials/2968829
# ...

# %%
months = {1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31}
moscow_19 = dict()
for month in tqdm_notebook(list(months.keys())):
    for day in tqdm_notebook(list(range(months[month]))):
        date = f'{day+1:02d}.{month:02d}.2019'
        moscow_19[f'2019.{month:02d}.{day+1:02d}'] = []
        for page in range(5):
            try:
                url = f'https://www.mskagency.ru/?criteria=%D0%B8&from={date}&to={date}&page={page+1}&last_date={date}&rnd=1&list_only=1'
                r = requests.get(url)
                soup = BS(r.text)
                links_temp = ['https://www.mskagency.ru'+a['href'] for a in soup.find_all('a', 'js-title')]
                moscow_19[f'2019.{month:02d}.{day+1:02d}'].extend(links_temp)
            except (AttributeError, IndexError, KeyError):
                print(date)

            if len(links_temp) < 50:
                print(f'2019.{month:02d}.{day+1:02d}', len(moscow_19[f'2019.{month:02d}.{day+1:02d}']))
                break
                
with open('moscow_links_2019.json', 'w', encoding = 'utf-8') as f:
    json.dump(moscow_19, f)
# Out:
# ...
# 2019.01.01 60
# 2019.01.02 56
# 2019.01.03 53
# 2019.01.04 47
# 2019.01.06 31
# 2019.01.07 43
# 2019.01.08 37
# 2019.01.09 114
# 2019.01.10 132
# 2019.01.11 94
# 2019.01.12 34
# 2019.01.13 27
# 2019.01.14 147
# 2019.01.15 195
# 2019.01.16 161
# 2019.01.17 160
# 2019.01.18 142
# 2019.01.19 49
# 2019.01.20 38
# 2019.01.21 113
# 2019.01.22 154
# 2019.01.23 141
# 2019.01.24 170
# 2019.01.25 151
# 2019.01.26 59
# 2019.01.27 36
# 2019.01.28 180
# 2019.01.29 155
# 2019.01.30 174
# ...
# 2019.02.01 135
# 2019.02.02 27
# 2019.02.03 25
# 2019.02.04 146
# 2019.02.05 170
# 2019.02.06 163
# 2019.02.07 149
# 2019.02.08 151
# 2019.02.09 25
# 2019.02.10 25
# 2019.02.11 129
# 2019.02.12 172
# 2019.02.13 189
# 2019.02.14 169
# 2019.02.15 129
# 2019.02.16 46
# 2019.02.17 32
# 2019.02.18 139
# 2019.02.19 174
# 2019.02.20 140
# 2019.02.22 146
# 2019.02.23 31
# 2019.02.24 23
# 2019.02.25 118
# 2019.02.26 138
# 2019.02.27 145
# 2019.02.28 155
# ...
# 2019.03.01 129
# 2019.03.02 42
# 2019.03.03 29
# 2019.03.04 123
# ...

# %%
# moscow_2019 = []
for date in tqdm_notebook(sorted(list(moscow_19.keys()))[1:]):
    for link in tqdm_notebook(moscow_19[date]):
        if link not in pd.DataFrame(moscow_2019).Link:
            try:
                r = requests.get(link)
                soup = BS(r.text)
                moscow_2019.append({'Media':'mskagency.ru', 'Date':date, 'Link':link,
                                      'Text':' '.join([soup.h1.text, ' '.join([p.text for p in soup.find('div', 'text').find_all('p')])]),
                                     'Dep':'', 'Tags':[]})
            except (requests.exceptions.ConnectionError, AttributeError, 
                    IndexError, requests.exceptions.TooManyRedirects, ValueError):
                print(link)
    if date.endswith('1'):
        pd.DataFrame(moscow_2019).to_csv('moscow_2019.csv', encoding='utf-8')
pd.DataFrame(moscow_2019).to_csv('moscow_2019.csv', encoding='utf-8')
pd.DataFrame(moscow_2019)
# Out:
# ...
# https://www.mskagency.ru/materials/2851707
# https://www.mskagency.ru/materials/2851681
# ...
# https://www.mskagency.ru/materials/2851765
# ...
# https://www.mskagency.ru/materials/2851923
# https://www.mskagency.ru/materials/2851921
# https://www.mskagency.ru/materials/2851919
# https://www.mskagency.ru/materials/2851923
# https://www.mskagency.ru/materials/2851921
# https://www.mskagency.ru/materials/2851919
# https://www.mskagency.ru/materials/2851923
# https://www.mskagency.ru/materials/2851921
# https://www.mskagency.ru/materials/2851919
# https://www.mskagency.ru/materials/2851923
# https://www.mskagency.ru/materials/2851921
# https://www.mskagency.ru/materials/2851919
# https://www.mskagency.ru/materials/2851923
# https://www.mskagency.ru/materials/2851921
# https://www.mskagency.ru/materials/2851919
# ...
# https://www.mskagency.ru/materials/2852151
# https://www.mskagency.ru/materials/2852111
# ...
# https://www.mskagency.ru/materials/2852645
# ...
# https://www.mskagency.ru/materials/2853139
# ...
